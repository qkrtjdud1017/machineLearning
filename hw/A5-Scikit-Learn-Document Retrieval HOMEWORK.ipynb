# %% [markdown]
# # Assignment 5 - Document Retrieval
#
# ### <span style="color:red">THIS IS HOMEWORK.</span>
# ### Due: May 15th, 11:59 pm on Canvas.
# > **Copyright ©2019 University of Washington**
#
# > **Emily Fox**, author of the TuriCreate based version of this assignment.
# > **Sewoong Oh**, instructor of CSE/STAT 416 for Spring 2019.
# > **Joshua Fan**, generously offered a LOT help in debugging and testing.
# > **Anna Neufeld**, generously offered a lot of help in code review.
# > **Hongjun Wu**, revisor of the Scikit-Learn based version of this assignment.
# > **All rights reserved.**
#
# ### Clarification
# * <span style="color:red">Read & post to this [Assignment 5 Clarifications](https://canvas.uw.edu/courses/1271722/discussion_topics/4817620) if you are not sure of something.</span>
# * Many of you have confusion on why some of your homeworks do not get full credit when you think you submitted the correct answer.
#     * Well, the answer is simple. If there's Free Response questions, we need to give credit after we manually look at your response.
#     * So yeah, don't panic. It's okay.
#
# ### Purpose
# * When exploring a large set of documents -- such as Wikipedia, news articles, StackOverflow, etc. -- it can be useful to get a list of related material.
# * To find relevant documents you typically:
#     * Decide on a notion of similarity
#     * Find the documents that are most similar
#
# ### Method & Summary
# * In the assignment you will:
#     * Gain intuition for different notions of similarity and practice finding similar documents.
#     * Explore the tradeoffs with representing documents using raw word counts and TF-IDF
#     * Explore the behavior of different distance metrics by looking at the Wikipedia pages most similar to President Obama’s page.
#
# ### Permission
# * Permission is hereby granted to students registered for University of Washington CSE/STAT 416.
# * For use solely during Spring Quarter 2019 for purposes of the course.
# * No other use, copying, distribution, or modification is permitted without prior written consent.
# * Copyrights for third-party components of this work must be honored.
# * Instructors interested in reusing these course materials should contact the author.
#
# > If you have any questions or you are unclear what we are refering to in this homework, please do not hesitate to reach out! Post a discussion and we would love to listen to and answer your questions. Hope you enjoy this assignment 😜 (Well I enjoyed writing it since ya don't get the chance to write emoji into CSE assignment prompt at 4AM very often)

# %% [markdown]
# # Nearest Neighbors

# %% [markdown]
# ### Import necessary packages
# * As usual we need to first import the Python packages that we will need.

# %%
# Import Statement, by now I guess you kinda know what these are use for? 
import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Magic Function (Like...magic)
# Interested? Don't know what it means? Read this!
# https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline
# %matplotlib inline

# Make Pandas print more stuff
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# > Again, stuff wrote in blockquotes is optional. Just something we think is useful to have around.

# %% [markdown]
# ### Load Wikipedia dataset
#
# * We will be using a dataset of Wikipedia pages. Each element of the dataset consists of a link to the wikipedia article, the name of the person, and the text of the article (in lowercase).
# * This time, since wikipedia is based on articles of some human, it is useful to let index be the names of the person.
# * Let's take an overlook at this dataset.
#
# #### Load Data Basics
# * First, we will load in all the wikipedia of people data from file using `pd.read_csv()`.
#
# > If you need the dataset:
# Download it in Canvas under [/files/Assignment Resources/data/](https://canvas.uw.edu/courses/1271722/files/folder/Assignment%20Resources/data).
#
# > If data failed to load:
# [1] Check if you have the correct file and is in the correct location!
# [2] Make sure you have `people_wiki.csv.csv`, not `people_wiki.csv.gl`!
#
# > Reminders:
# `'./'` means that you are finding a file within the same directory as the notebook.
# `'../'` means that you are looking for a file or folder one hierarchy above.

# %%
wiki = pd.read_csv('/data/people_wiki.csv', index_col='name')

# %% [markdown]
# * What do the contents look like?

# %%
wiki[0:5]
# Out:
#                                                                    URI                                               text
# name
# Digby Morrell              <http://dbpedia.org/resource/Digby_Morrell>  digby morrell born 10 october 1979 is a former...
# Alfred J. Lewy            <http://dbpedia.org/resource/Alfred_J._Lewy>  alfred j lewy aka sandy lewy graduated from un...
# Harpdog Brown              <http://dbpedia.org/resource/Harpdog_Brown>  harpdog brown is a singer and harmonica player...
# Franz Rottensteiner  <http://dbpedia.org/resource/Franz_Rottensteiner>  franz rottensteiner born in waidmannsfeld lowe...
# G-Enka                            <http://dbpedia.org/resource/G-Enka>  henry krvits born 30 december 1974 in tallinn ...

# %% [markdown]
# * What is the overall scale?

# %%
print(wiki.shape)
# Out:
# (59071, 2)

# %% [markdown]
# ## Identify Useful Features
# * A lot times, the dataset we get usually contain a huge amount of features(Think of some of the datasets we used before, which has quite a lot of features).
# * Remember that adding one more feature means add one more dimension space when computing distances, which sucks since the level of computation difficulity goes up rapidly.
#     * This is sometimes called "The Curse of Dimensionality". Ugh! 🤯
# * It is up to us to decide which to use.
#     * In some cases, we can use feature selection to find out which feature to use.
#         * Remember LASSO? LASSO is really good at eliminating features.
#         * 🤜 = LASSO, 👿 = Features
#         * 🧐🤜👿👻👻👿👻👿👻👻👻👻👻👻
#     * In other cases, it is obvious to a human which feature is useful. Yep, we are talking about this dataset.
#         * In this case, we have two features in the dataset. Namely, "URL" and "text".
#             * Which one is important to us? Obviously url cannot give us much information when it comes to find nearest articles of famous humans, so we can get rid of it.
#             * 🧐🤜👿👻

# %%
wiki[0:5]
# Out:
#                                                                    URI                                               text
# name
# Digby Morrell              <http://dbpedia.org/resource/Digby_Morrell>  digby morrell born 10 october 1979 is a former...
# Alfred J. Lewy            <http://dbpedia.org/resource/Alfred_J._Lewy>  alfred j lewy aka sandy lewy graduated from un...
# Harpdog Brown              <http://dbpedia.org/resource/Harpdog_Brown>  harpdog brown is a singer and harmonica player...
# Franz Rottensteiner  <http://dbpedia.org/resource/Franz_Rottensteiner>  franz rottensteiner born in waidmannsfeld lowe...
# G-Enka                            <http://dbpedia.org/resource/G-Enka>  henry krvits born 30 december 1974 in tallinn ...

# %%
wiki = wiki['text']

# %%
wiki[0:5]
# Out:
# name
# Digby Morrell          digby morrell born 10 october 1979 is a former...
# Alfred J. Lewy         alfred j lewy aka sandy lewy graduated from un...
# Harpdog Brown          harpdog brown is a singer and harmonica player...
# Franz Rottensteiner    franz rottensteiner born in waidmannsfeld lowe...
# G-Enka                 henry krvits born 30 december 1974 in tallinn ...
# Name: text, dtype: object

# %% [markdown]
# * We will also save this version of wiki the `original_wiki`, so we may come back later in this assignment.
#     * The idea is that we will perform similiar computation processes using two ways of vectorizing.
#     * So maintain a copy of the original dataset is useful, you will see what we mean soon.

# %%
original_wiki = wiki

# %% [markdown]
# * Now that we only have name versus their page, we can finally dig into some sweet nearest neighbor search machine learning. 😏

# %% [markdown]
# ## Extract word count vectors

# %% [markdown]
# We can extract word count vectors using a function called `CountVectorizer()`.
# * [sklearn.feature_extraction.text.CountVectorizer()](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html)
#
# > #### Some more detailed explainations on vectorizing:
# * It says in the documentation it "Convert a collection of text documents to a matrix of token counts", but what does this mean?
# * Naturally, what we think of doing is to make a dictionary of word counts,
#     * So let's say for "bound le s s boi" you will have a dictionary of {bound:1, le: 1, s:2, boi:1}
#     * But imagine we do that for many words in many texts...
#         * That is a lot of different vectors in a lot of dictionaries!
#         * 59071 of them! And they take a lot of spaceeeeeeeeeeeeeeeeeee🌌
#         * But more importantly, such data structure is very inefficient when it comes to querying.
#     * But this does NOT mean it is useless. We will see them later in this homework.
# * So to store them efficiently and make them easy to query, we will tokenize these vectors and put them into a matrix.
#     * Namely, we don't store individual dictionaries in each row, but make a list of names and align them to a matrix's column.
#     * What does this matrix look like? Think if we have a matrix with each column for a word, and each row for an article, take a second to think how crowded this matrix might look like.
#         * Not very croweded, right?
#         * For example, the column for 'obama' will only have a value if that human is obama-related.
#         * Say we take Queen Victoria, she doesn't know Obama, she isn't even an American and not to mention she is dead many years before Obama is born, so I guess her 'obama' column very likely be zero. Same for many, many other humans. We call a matrix with many zeroes "sparse".
#         * Still, such a matrix takes up a lot of spaceeeeeee.
#             * But it is MUCH easier for our lovely computer to query.
#     * Fortunatelly, we have an effecient way to store it in Scikit-Learn's datastructure.
#         * How it works? Well, it is complicated, but the main idea is It saves space by not saving zeroes, therefore reduce the amount of space we take in the memory.

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer()
count_matrix = count_vectorizer.fit_transform(wiki)

# %% [markdown]
# >### Let's take a look at what is this matrix.
# * As we talked about in the previous blockquote, it is stored in a "sparse matrix" data structure implemented by some smart humans.

# %%
count_matrix
# Out:
# <59071x548429 sparse matrix of type '<class 'numpy.int64'>'
# 	with 10244028 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### While we are here, let's take a look at (some of) the features of the giant matrix as well.
# * Let's give it a shot 100000. Never seen this many features in the assignment...
# * We try hart to scroll down, but we can't even reach the words start with `c`.
# * That's 100000 columns! If we call `print(count_vectorizer.get_feature_names())`and attempt to print all the feature names, python will likely explode...
# * Crazy, right?

# %%
print(count_vectorizer.get_feature_names()[0:100000])
# Out:
# ['00', '000', '0000', '00000', '00000van', '0001', '00014338', '0001sec', '0002', '00026', '0003', '0005', '000577', '0005sec', '0006', '0007', '0007105916', '0007200374', '0007207328', '0007213506', '000721426xhe', '0007a', '000he', '000in', '000m', '000seelenprojekt', '000tnmickushina', '001', '0017', '001cd', '001ehebbm', '002', '0020849605', '0024', '0026183900', '002864574x', '0028659287', '003', '0033', '0034', '0036', '004', '0043', '0046', '004erdemir', '005', '006', '0060222425', '0060628227', '0060628464', '0060669667', '006074393x', '0064', '0066', '007', '0070710481', '0071357440', '0071375627', '0072131772', '0072131896', '0072222611', '0072225351', '0072438886', '007all', '008', '0080', '0080357547', '008after', '009', '00906603', '0091', '0091857112', '0091900255she', '0099416689', '009at', '00a10', '00g', '00s', '00sex', '00sin', '01', '010', '0100', '01000400', '01011001', '01011001i', '0102', '0102928045since', '010397', '01041984', '010602he', '0108', '011', '0110', '01122005', '0113554', '011708', '012', '0123039606', '013', '013011510x', '0131232746', '0139738509', '014', '0140265708', '0140280553', '0143', '014a', '015', '0158', '016', '016a', '017', '017384251', '018', '0186', '0195104633dr', '0195140532winifred', '0198', '0198149417', '0198150784', '0198155409', '0198162073', '0198269862', '0198299966judaism', '01analyzing', '01consulting', '01he', '01jazz', '01kwh', '01net', '01oct1952', '01shave', '01st', '01w', '02', '020', '0200', '0201083191', '020114218x', '02011964', '020139829x', '0201498278he', '0201533774', '020158042x', '0201580438', '0201725932', '0202361373', '0203', '02032010', '0205', '0208', '021', '021050', '021206', '021207his', '02138', '02182748', '022', '022009', '02202020', '0225662434', '0225662434the', '0226727033', '022under', '023', '0231115113', '0233976817', '024', '0240804120winder', '0240814215', '024cd', '025', '0252009851we', '0252014278', '0252070003', '026', '0262195224', '0262521563', '0262524570', '027', '0273', '0273langton', '0275938514', '028', '0282', '029', '0295973390', '0295974982', '02au', '02he', '02the', '03', '030', '0300', '0300051115paul', '0304', '03072010', '03082008', '031', '0310227283', '0312022484', '0312038054', '0312151918', '0312199228', '0312360398', '0312913451', '0313313326professor', '031538736', '0316346624', '0316359564', '032', '0321186125an', '0321187911', '0321422775balancing', '0321461088cmmi', '033', '0330482688', '034', '034042320x', '0340428910', '0340500719', '0340524553', '0340551097', '0340565403', '0340579714', '0340579730', '0340628588', '0340832118', '0345373065waiting', '035', '036', '037', '0373892101', '0375411852joint', '03790', '038', '0380751089review', '038075343xreview', '0380755203as', '0380898527review', '03824', '038518011x', '0387', '0387942890', '0393039153', '0393058697', '039306073x', '0394537173the', '0394546032broadsides', '03945771243', '0395827442', '0395837030sue', '0395883245a', '0399513329', '039951810x', '03his', '04', '040', '0400', '04012015', '0403', '040407', '0405', '040612', '0407', '040he', '041', '04122006he', '0413776565bigsby', '0415049709', '042', '04242018', '04312417676', '0434', '04350925', '044', '0440223857netter', '0441', '0443073457', '0446329673', '0446696749', '045', '0450048047in', '04522599832', '046', '0465045677metzingers', '0465091148', '047', '0470179147', '0470540710moffitt', '0470834005', '0470838515', '0471250376', '0471417920', '0471489093', '0471597376in', '0471683345', '0471792519in', '0471833568', '0471971979', '0471971987', '0472114190shrinking', '048', '0485w', '0486', '049', '0499', '04journalist', '04nikon', '04s', '04th', '05', '050', '0500251126the', '0500274959', '0500506', '05012011', '050187', '0503', '0504', '05042008', '05042012', '0505', '0506', '050607', '051', '0512after', '0515', '05151992', '0517078074', '0517705427', '051989after', '052', '0520207343', '052020735', '0521207886matthew', '052124160x', '0521416957', '0521447828', '0521582741', '0521816262', ' ...

# %%
# I know some of you want to try this after I said it...well in default settings Python would explode.
# print(count_vectorizer.get_feature_names())

# %% [markdown]
# ## Find nearest neighbors

# %% [markdown]
# * Now, it's our turn! 🤩
# * Let's start by finding the nearest neighbors of the Barack Obama page using the word count vectors to represent the articles and Euclidean distance to measure distance.  For this, again will we use a Scikit-Learn implementation of nearest neighbor search.
# * We begin by constructing a model, then fit with the matrix.
# * Since we want to see the ten related neighbors of Obama, please set `n_neighbors=10` when you are constructing the model.
#     * [sklearn.neighbors.NearestNeighbors](https://scikit-learn.org/stable/modules/neighbors.html)

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(n_neighbors=10)
model.fit(count_matrix)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=None, n_neighbors=10, p=2, radius=1.0)

# %% [markdown]
# ### Let's look at the top 10 nearest neighbors by performing the following query.
# * Originally, the assignment from last year will just run a block of code and show you the top ten.
# * But since many of you told us you'd like to know a bit more what some of the given code means, let's walk through it.
#
# * First, we need to get "Barack Obama".

# %%
obama = count_matrix.getrow(wiki.index.get_loc('Barack Obama'))  # First, we find the "Obama Row".
obama
# Out:
# <1x548429 sparse matrix of type '<class 'numpy.int64'>'
# 	with 270 stored elements in Compressed Sparse Row format>

# %% [markdown]
# * Then, let's look at what the `kneighbors()` give us.
#     * The first element is distance from other articles, whereas the second element is the index of the word in the matrix.
#     * You can read more about kneighbors() here: [kneighbors(X=None, n_neighbors=None, return_distance=True)](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier.kneighbors)

# %%
model.kneighbors(obama)
# Out:
# (array([[ 0.        , 33.01514804, 34.3074336 , 35.79106034, 36.06937759,
#          36.24913792, 36.27671429, 36.40054945, 36.44173432, 36.83748091]]),
#  array([[35817, 24478, 28447, 14754, 35357, 31423, 13229, 36364, 22745,
#           7660]]))

# %% [markdown]
# * Well then, let's save the distances and indices.

# %%
dist = model.kneighbors(obama)[0]
index = model.kneighbors(obama)[1]

# %% [markdown]
# * Now, let's find similar names.
#     * Wait! Remember, the wiki data has `names` as index, whereas the matrix has an numerical index.

# %%
wiki[0:5]
# Out:
# name
# Digby Morrell          digby morrell born 10 october 1979 is a former...
# Alfred J. Lewy         alfred j lewy aka sandy lewy graduated from un...
# Harpdog Brown          harpdog brown is a singer and harmonica player...
# Franz Rottensteiner    franz rottensteiner born in waidmannsfeld lowe...
# G-Enka                 henry krvits born 30 december 1974 in tallinn ...
# Name: text, dtype: object

# %% [markdown]
# * So first, we will need to get the numerical indices back by using `reset_index()`.
#     * It really just adds a numerical index to the dataset.
#     * Why? Because we need an index to represent everybody's names.

# %%
new_wiki = wiki.reset_index()['name']
new_wiki[0:5]
# Out:
# 0          Digby Morrell
# 1         Alfred J. Lewy
# 2          Harpdog Brown
# 3    Franz Rottensteiner
# 4                 G-Enka
# Name: name, dtype: object

# %% [markdown]
# * Here, we will use a function called `pandas.Index.flatten()` that breaks an nD array into an 1D array.
#     * Note the difference between before flatten and after flatten.
#         * It used to be a 2D array `array([[]])`, but we flattened it to be an `array([])`.
#         * So we can perform familiar operations with 1D array.
#     * [pandas.Index.flatten()](http://pandas.pydata.org/pandas-docs/version/0.14/generated/pandas.Index.flatten.html)

# %%
index
# Out:
# array([[35817, 24478, 28447, 14754, 35357, 31423, 13229, 36364, 22745,
#          7660]])

# %%
flat_index = index.flatten()
flat_index
# Out:
# array([35817, 24478, 28447, 14754, 35357, 31423, 13229, 36364, 22745,
#         7660])

# %% [markdown]
# * Similarly, we flatten the distances.
#     * Now we have our distances and index as two separate 1D array.

# %%
distances = dist.flatten()
distances
# Out:
# array([ 0.        , 33.01514804, 34.3074336 , 35.79106034, 36.06937759,
#        36.24913792, 36.27671429, 36.40054945, 36.44173432, 36.83748091])

# %% [markdown]
# * Now we need to match the names with the distances.
#     * Quick reminder: Remember when we talked in the very first quiz section that DataFrames are constructed with Series?
#     * Think of series as one individual column.
#     * Let's make that column.

# %%
series_index = pd.Series(flat_index)

# %% [markdown]
# * Now, let's map every index to their names.

# %%
names = series_index.map(new_wiki)
names
# Out:
# 0                  Barack Obama
# 1                     Joe Biden
# 2                George W. Bush
# 3                   Mitt Romney
# 4              Lawrence Summers
# 5                Walter Mondale
# 6              Francisco Barrio
# 7                    Don Bonker
# 8    Wynn Normington Hugh-Jones
# 9      Refael (Rafi) Benvenisti
# dtype: object

# %% [markdown]
# * Finally, let's stitch the names with their distances together, and see what the outcome is.

# %%
result = pd.DataFrame({'distance':distances, 'name':names})
result
# Out:
#     distance                        name
# 0   0.000000                Barack Obama
# 1  33.015148                   Joe Biden
# 2  34.307434              George W. Bush
# 3  35.791060                 Mitt Romney
# 4  36.069378            Lawrence Summers
# 5  36.249138              Walter Mondale
# 6  36.276714            Francisco Barrio
# 7  36.400549                  Don Bonker
# 8  36.441734  Wynn Normington Hugh-Jones
# 9  36.837481    Refael (Rafi) Benvenisti

# %% [markdown]
# * Whoa! That really took quite a while to write, but hopefully this helps.😄
#
# ### Now let's take a look at the humans we think is close to Obama!

# %% [markdown]
# * All of the 10 people are politicians, but about half of them have rather tenuous connections with Obama, other than the fact that they are politicians.
#
#     * Francisco Barrio is a Mexican politician, and a former governor of Chihuahua.
#     * Walter Mondale and Don Bonker are Democrats who made their career in late 1970s.
#     * Wynn Normington Hugh-Jones is a former British diplomat and Liberal Party official.
#     * Refael (Rafi) Benvenisti is a economist from Israel.
#
# * Nearest neighbors with raw word counts got some things right, showing all politicians in the query result, but missed finer and important details.
#
# * For instance, let's find out why Francisco Barrio was considered a close neighbor of Obama.  To do this, let's look at the most frequently used words in each of Barack Obama and Francisco Barrio's pages:

# %%
def top_words(name):
    # Get the most frequent words in the given person's wikipedia page.
    word = count_matrix.getrow(wiki.index.get_loc(name)).toarray().flatten()
    indices = count_vectorizer.get_feature_names()
    words = pd.Series(word, index = indices)
    words = words.sort_values(ascending=False).reset_index()
    words.rename(columns={'index':'word',0:'count'}, inplace=True)
    return words

# %%
obama_words = top_words('Barack Obama')
obama_words[0:10]
# Out:
#     word  count
# 0    the     40
# 1     in     30
# 2    and     21
# 3     of     18
# 4     to     14
# 5    his     11
# 6  obama      9
# 7    act      8
# 8     he      7
# 9     us      6

# %%
barrio_words = top_words('Francisco Barrio')
barrio_words[0:10]
# Out:
#         word  count
# 0        the     36
# 1         of     24
# 2        and     18
# 3         in     17
# 4         he     10
# 5         to      9
# 6  chihuahua      7
# 7   governor      6
# 8         as      5
# 9        his      5

# %% [markdown]
# * (chihuahua was mentioned seven times in Barrio's words. What a sweet man!)

# %% [markdown]
# ## Obama and Barrio comparison

# %% [markdown]
# Let's extract the list of most frequent words that appear in both Obama's and Barrio's documents. We've so far sorted all words from Obama and Barrio's articles by their word frequencies. We will now use a dataframe operation known as **join**. The **join** operation is very useful. when it comes to playing around with data: it lets you combine the content of two tables using a shared column (in this case, the word column). See [the documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html) for more details.
#
# For instance, running
# ```
# obama_words.join(barrio_words.set_index('word'),rsuffix='_1', on = 'word')
# ```
# will extract the rows from both tables that correspond to the common words.

# %%
combined_words = obama_words.join(barrio_words.set_index('word'),rsuffix='_1', on = 'word')
combined_words[0:6]
# Out:
#   word  count  count_1
# 0  the     40       36
# 1   in     30       17
# 2  and     21       18
# 3   of     18       24
# 4   to     14        9
# 5  his     11        5

# %% [markdown]
# Since both tables contained the column named `count`, the function we wrote automatically renamed one of them to prevent confusion by adding `rsuffix='_1'`. Let's rename the columns to tell which one is for which. By inspection, we see that the first column (`count`) is Obama and the second (`count.1`) for Barrio.

# %%
combined_words.rename(columns={'count':'Obama','count_1':'Barrio'}, inplace=True)
combined_words[0:6]
# Out:
#   word  Obama  Barrio
# 0  the     40      36
# 1   in     30      17
# 2  and     21      18
# 3   of     18      24
# 4   to     14       9
# 5  his     11       5

# %% [markdown]
# **Note**. The **join** operation does not enforce any particular ordering on the shared column. So to obtain, say, the five common words that appear most often in Obama's article, sort the combined table by the Obama column. Don't forget `ascending=False` to display largest counts first.

# %%
combined_words.sort_values('Obama', ascending = False)[0:5]
# Out:
#   word  Obama  Barrio
# 0  the     40      36
# 1   in     30      17
# 2  and     21      18
# 3   of     18      24
# 4   to     14       9

# %% [markdown]
# * Remember when we said word count vector dictionaries aren't completely useless a while ago?
#     * Turns out it is very useful to construct such a column with dictionaries if we want to compare articles with their common words.
#     * Why?
#         * Each document has far less than all the words there is among all documents. It is much easier to compare two small dictionaries if they have common keys.

# %%
def word_counter(string):
    counts = dict()
    words = string.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

wiki = wiki.reset_index()
wiki['word_count'] = wiki['text'].apply(word_counter)

# %%
wiki[0:5]
# Out:
#                   name                                               text                                         word_count
# 0        Digby Morrell  digby morrell born 10 october 1979 is a former...  {'digby': 1, 'morrell': 5, 'born': 1, '10': 1,...
# 1       Alfred J. Lewy  alfred j lewy aka sandy lewy graduated from un...  {'alfred': 1, 'j': 1, 'lewy': 3, 'aka': 1, 'sa...
# 2        Harpdog Brown  harpdog brown is a singer and harmonica player...  {'harpdog': 2, 'brown': 2, 'is': 7, 'a': 7, 's...
# 3  Franz Rottensteiner  franz rottensteiner born in waidmannsfeld lowe...  {'franz': 1, 'rottensteiner': 3, 'born': 1, 'i...
# 4               G-Enka  henry krvits born 30 december 1974 in tallinn ...  {'henry': 1, 'krvits': 1, 'born': 1, '30': 1, ...

# %% [markdown]
# Among the words that appear both in Barack Obama and Francisco Barrio pages, take the 5 that appear most frequently in Obama. Identify the articles in the Wikipedia dataset that contain all of these 5 words.
#
# Hint:
# * Refer to the previous paragraph for finding the words that appear in both articles. Sort the common words by their frequencies in Obama's article and take the largest five.
# * Each word count vector is a Python dictionary. For each word count vector, you'd have to check if the set of the 5 common words is a subset of the keys of the word count vector. Complete the function `has_top_words` to accomplish the task.
#   - Convert the top 5 words into set using the syntax
# ```
# set(top_words)
# ```
#     where `top_words` is a Pandas series.
#   - Use [`issubset()` method](https://www.programiz.com/python-programming/methods/set/issubset) to check if all 5 words are among the keys.
# * We will apply the `has_top_words` function on every row of the Pandas DataFrame in a bit, and we provided the code for you to apply.
# * Compute the sum of the result column to obtain the number of articles containing all the 5 top words.
#     * For Q1.

# %%
# ### Write your code here!
combined_words = obama_words.join(barrio_words.set_index('word'),rsuffix='_1', on = 'word')
combined_words.rename(columns={'count':'Obama','count_1':'Barrio'}, inplace=True)
# common_words
# print(combined_words)
common_words = set(combined_words.sort_values('Obama', ascending = False)['word'][0:5])
print(common_words)
def has_top_words(word_count_vector):
    unique_words = word_count_vector.keys()
    if common_words.issubset(unique_words):
        return True
    else:
        return False
    # return True if common_words is a subset of unique_words
    # return False otherwise
#     return ...
# Out:
# {'and', 'in', 'of', 'the', 'to'}

# %% [markdown]
# Check your `has_top_words` function on two random articles:
# * Write a function called `print_unique()` that takes in a `dict` of `word_count_vector` and prints out the Length of unique words in that word_count_vector.
# * Then, use that to check the length of the documents at index `32` and `33`.

# %%
print('Output from your function:', has_top_words(wiki.iloc[32]['word_count']))
print('Correct output: True')
print('Also check the length of unique_words. It should be 167.')
# Out:
# Output from your function: True
# Correct output: True
# Also check the length of unique_words. It should be 167.

# %%
# Write your check length of unique words here!
def print_unique(word_count_vector):
    print(len(word_count_vector.keys()))
print_unique(wiki.iloc[32]['word_count'])
# Out:
# 167

# %%
print('Output from your function:', has_top_words(wiki.iloc[33]['word_count']))
print('Correct output: False')
print('Also check the length of unique_words. It should be 188.')
# Out:
# Output from your function: False
# Correct output: False
# Also check the length of unique_words. It should be 188.

# %%
# Write your check length of unique words here!
print_unique(wiki.iloc[33]['word_count'])
# Out:
# 188

# %% [markdown]
# * Below is a simple function that applies the function to `word_count` and make a new column called `has_top_words`.

# %%
wiki['has_top_words'] = wiki['word_count'].apply(has_top_words)

# %% [markdown]
# ### **Q1) Among the words that appear both in Barack Obama and Francisco Barrio pages, take the 5 that appear most frequently in Obama. What percentage of the articles in the Wikipedia dataset contain all of these top 5 words? Give answer as a decimal rounded to the nearest 0.0001 - for instance if the percentage found was 19.26% then state answer as 0.1926.** 0.9491
# * Fun fact...do you know you can sum up booleans in Python using `sum()` as well?
#     * Python will treat True as 1, and False as 0 if it ask it to sum up a bunch of booleans.

# %%
# Write your answers here!
wiki['has_top_words'].sum()/len(wiki['has_top_words'])
# Out:
# 0.9491290142371045

# %% [markdown]
# ## Pairwise distances

# %% [markdown]
# * Now measure the pairwise distance between the Wikipedia pages of Barack Obama, George W. Bush, and Joe Biden.
#
# * Hint:
#     * Before everything else, let's come back to original_wiki, which is the wiki dataframe we first obtained.
#         * Why use that wiki? Because you can then easily get the row from the word count matrix we obtained before.
#         * We performed similar operations before in this assignment! Remember...how did we find the obama row?
#     * To compute the Euclidean distance between two rows, use `sklearn.metrics.pairwise.euclidean_distances`. Refer to [this link](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.euclidean_distances.html) for usage.

# %%
# Revert wiki back to the original
wiki = original_wiki
wiki
# Out:
# name
# Digby Morrell                               digby morrell born 10 october 1979 is a former...
# Alfred J. Lewy                              alfred j lewy aka sandy lewy graduated from un...
# Harpdog Brown                               harpdog brown is a singer and harmonica player...
# Franz Rottensteiner                         franz rottensteiner born in waidmannsfeld lowe...
# G-Enka                                      henry krvits born 30 december 1974 in tallinn ...
# Sam Henderson                               sam henderson born october 18 1969 is an ameri...
# Aaron LaCrate                               aaron lacrate is an american music producer re...
# Trevor Ferguson                             trevor ferguson aka john farrow born 11 novemb...
# Grant Nelson                                grant nelson born 27 april 1971 in london also...
# Cathy Caruth                                cathy caruth born 1955 is frank h t rhodes pro...
# Sophie Crumb                                sophia violet sophie crumb born september 27 1...
# Jenn Ashworth                               jenn ashworth is an english writer she was bor...
# Jonathan Hoefler                            jonathan hoefler born august 22 1970 is an ame...
# Anthony Gueterbock, 18th Baron Berkeley     anthony fitzhardinge gueterbock 18th baron ber...
# David Chernushenko                          david chernushenko born june 1963 in calgary a...
# Joerg Steineck                              joerg steineck is a german filmmaker editor an...
# Andrew Pinsent                              fr andrew pinsent born 19 august 1966 is resea...
# Paddy Dunne (Gaelic footballer)             paddy dunne was a gaelic football player from ...
# Alexandros Mouzas                           alexandros mouzas born 1962 is a greek compose...
# John Angus Campbell                         john angus campbell born march 10 1942 in port...
# Chris Batstone                              chris batstone was the 20002002 lead singer of...
# Ceiron Thomas                               ceiron thomas born 23 october 1983 is a welsh ...
# Adel Sellimi                                adel sellimi arabic was born on 16 november 19...
# Faith Soloway                               faith soloway born march 28 1964 is an america...
# Tom Jennings                                tom jennings born 1955 as thomas daniel jennin...
# Vic Stasiuk                                 victor john stasiuk born may 23 1929 is a reti...
# Anthony Caruana                             anthony caruana born 2 january 1968 is a melbo...
# Ian Mitchell (author)                       ian mitchell is a scottish author who grew up ...
# Leon Hapgood                                leon duane hapgood born 7 august 1979is an eng...
# Emily Osment                                emily jordan osment born march 10 1992 is an a...
# Dom Flora                                   dominick a dom flora born june 12 1935 is an a...
# Ted Hill (mathematician)                    theodore preston hill born december 28 1943 is...
# Mindaugas Murza                             mindaugas gervaldas until 2012 year mindaugas ...
# Bob Reece                                   robert scott reece born january 5 1951 is an a...
# Douglas Davies                              douglas james davies born 1947 is professor in...
# Freimut B%C3%B6rngen                        freimut brngen born october 17 1930 is a germa...
# Th%C3%BCring Br%C3%A4m                      thring brm born 10 april 1944 is a swiss compo...
# Aharon Solomons                             aharon solomons b september 27 1939 is a freed...
# Steven Weil                                 steven weil is an american rabbi who grew up o...
# Gary Emineth                                gary emineth born october 24 1958 is a politic...
# Timothy Grucza                              timothy grucza born 1 july 1976 melbourne aust...
# Bob Adams (American football)               robert bruce bob adams born august 15 1946 in ...
# Sylvie Roy                                  sylvie roy born november 4 1964 in la tuque qu...
# Rob Sheffield                               rob sheffield born february 2 1966 is an ameri...
# Michel Che                                  professor michel che born in lyon france compl...
# Jaafar Aksikas                              jaafar aksikas born 1974 in azemmour morocco i...
# Will Tuttle                                 will m tuttle born 1953 is an american writer ...
# Vanessa Ament                               dr vanessa theme ament born january 8 1955 in ...
# Marc Logan                                  marc anthony logan born may 9 1965 is a former...
# Corey Woolfolk                              corey woolfolk born february 26 1983 in ann ar...
# Professor Lyrical (rapper)                  professor lyrical is a hip hop artist from low...
# Michelle Ye                                 michelle ye or ye xuan born february 14 1980 i...
# Robert N. Chatigny                          robert neil chatigny born 1952 taunton ma is a...
# Vincent Fang (lyricist)                     for a hong kong entrepreneur please refer to v...
# Misa Telefoni Retzlaff                      misa telefoni retzlaff born hermann theodor re...
# Mary Goldring                               mary goldring obe is a british business journa...
# Susan Westerberg Prager                     susan westerberg prager 1942 is an american le...
# Yohannes Yual                               yohannes yual both or johannes yoal bath etc w...
# Christopher Sorrentino                      christopher sorrentino born may 20 1963 is an ...
# Alexis Bhagat                               alexis bhagat is a writer and curator in new y...
# David Vernon Williams                       professor david vernon williams is a professor...
# Guillermo Roux                              guillermo roux born in 1929 is an argentine pa...
# William J. Ely                              william jonas ely jr born december 29 1911 is ...
# Alan Roper                                  alan roper born may 1939 in tipton staffordshi...
# Bob Havens                                  bob havens born may 3 1930 is an american big ...
# Susan Christie                              susan christie is an american singersongwriter...
# Elizabeth Gunn (author)                     elizabeth gunn is an american author of myster...
# Bo Hampton                                  bo hampton born 1954 in united states is a not...
# Milva                                       maria ilva biolcati commander omri italian pro...
# Will Tiao                                   will tiao is a taiwanese american actor and pr...
# Quintin E. Primo III                        quintin e primo iii born march 14 1955 is the ...
# Geoffrey Bayldon                            geoffrey bayldon born 7 january 1924 in leeds ...
# Ulf-Dietrich Reips                          prof dr ulfdietrich reips is a full professor ...
# Marcel J. Melan%C3%A7on                     marcel j mlanon is a philosopher and scientist...
# Mike Powell (journalist)                    mike powell is a british former newspaper and ...
# Vladimir Yurchenko                          uladzimir vasilyevich yurchanka belarusian rus...
# Nobuo Uematsu                               nobuo uematsu uematsu nobuo born march 21 1959...
# John Warner (writer)                        john warner born 1970 is an american writer an...
# Doug McIntosh                               doug mcinstosh is a retired american basketbal...
# Avi Muchnick                                avi muchnick born 1979 is an artist author pro...
# Robin MacPherson                            robin macpherson born 1959 glasgow scotland is...
# Judi Silvano                                judi silvano born 1951 is a jazz singer and co...
# Evelin Lindner                              evelin gerda lindner born may 13 1954 in hamel...
# Robert S. Gold                              robert s gold is a researcher in the applicati...
# Agnes Baltsa                                agnes baltsa greek a m born 19 november 1944 i...
# Zvonimir Juri%C4%87                         zvonimir juri born 4 june 1971 is a croatian f...
# John-Paul Himka                             johnpaul himka born may 18 1949 in detroit mic...
# Elisha Qimron                               elisha qimron is an academic in the study of a...
# Robert Grant Irving                         robert grant irving phd is an author and lectu...
# Sam Leach (artist)                          sam leach born 1973 is an emerging australian ...
# Patricia Crowther (caver)                   this article is about the cave explorer for th...
# Katja Herbers                               katja mira herbers dutch pronunciation ktja mi...
# Shaka Hislop                                neil shaka hislop cm born 22 february 1969 is ...
# Martin Iveson                               martin iveson is a british composer known for ...
# Eva Habermann                               eva felicitas habermann born january 16 1976 i...
# Steve Castle                                steve castle born 17 may 1966 in barking is a ...
# Armen Ra                                    armen ra is an american artist and performer o...
# David Shaughnessy                           david james shaughnessy also spelled shaughnes...
# John Reynolds (Canadian politician)         john douglas reynolds pc born january 19 1942 ...
# Dean Greig                                  dean greig born 31 october 1968 is a former au...
# Maha el-Samnah                              maha elsamnah born 1957 has canadian citizensh...
# James Stewart (American football)           james ottis stewart born december 27 1971 is a...
# Fredrik Jacobson                            fredrik ulf yngve jacobson born 26 september 1...
# Anerood Jugnauth                            sir anerood jugnauth kcmg qc gcsk pc born 29 m...
# Khalid Khannouchi                           khalid khannouchi arabic born september 12 197...
# Juan Pablo Montoya                          juan pablo montoya roldn born september 20 197...
# Ichikawa Ennosuke III                       ichikawa ennosuke iii sandaime ichikawa ennosu...
# Shirley Erena Murray                        shirley erena murray born 31 march 1931 is a n...
# Cajjmere Wray                               cajjmere wray aka ccw is a canadian producer d...
# Anna Kournikova                             anna sergeyevna kournikova russian ipa an srej...
# Abdel Fattah el-Sisi                        abdel fattah saeed hussein khalil elsisi arabi...
# Frank Millar Jr                             frank millar is a northern irish journalist an...
# Angus Clark                                 angus clark is a guitarist singer songwriter a...
# Casey McKee                                 casey mckee born 1976 phoenix arizona is an am...
# Al Hairston                                 alan leroy al hairston born december 11 1945 i...
# Albert Apuzzi                               albert apuzzi is a pharmacist and onewall hand...
# Ron Shuman                                  ron shuman born september 15 1952 is an americ...
# Christine Langan                            christine langan born january 1965 is an engli...
# Bill Young (Australian rules footballer)    william d bill young born 6 june 1931 is a for...
# Kenneth James Gibson                        kenneth james gibson born october 8 1973 is a ...
# Bruce Tulloh                                michael bruce swinton tulloh born 29 september...
# Oscar Milani                                oscar milani was born in rosario argentina nov...
# Se%C3%A1n %C3%93g %C3%93 hAilp%C3%ADn       sen g hailpn born 22 may 1977 is a fijianirish...
# Mike Trebilcock                             michael mike trebilcock born 29 november 1944 ...
# John Edmondson (musician)                   for the australian ww2 victoria cross medal aw...
# Ramiro Torres                               ramiro torres is a boston massachusetts area r...
# Steven Point                                steven lewis point obc xw l qwl tl born july 2...
# Victor Clube                                stace victor murray clube born 22 october 1934...
# Viktoriya Yermolyeva                        viktoriya yermolyeva ukrainian born november 2...
# L%C3%A1zaro C%C3%A1rdenas Batel             lzaro crdenas batel born april 2 1964 in jiqui...
# Moana Jackson                               moana jackson is a new zealand mori lawyer spe...
# Carlos Bea                                  carlos tiburcio bea born april 18 1934 is a fe...
# Hossein Modarressi                          hossein modarressi is a leading muslim jurist ...
# Joseph Massucci                             joseph massucci born in pittsburgh pennsylvani...
# Gregory Charles Rivers                      gregory charles rivers chinese cantonese ho kw...
# Angela Conner                               angela conner frbs is an english sculptor who ...
# Erik Marcisak                               erik marcisak pronounced marseesack born march...
# Daniel Falzon                               daniel lawson falzon born 16 march 1994 is a p...
# Conrad Phillip Kottak                       conrad phillip kottak born october 6 1942 in a...
# Marilyn Hall Patel                          marilyn hall patel born 1938 is a retired fede...
# Qiu Zhijie                                  qiu zhijie born 1969 is a contemporary chinese...
# Allison Booth                               alison booth is the author of the jingera tril...
# Yolande Thibeault                           yolande thibeault born october 8 1939 in montr...
# Annie Ernaux                                annie ernaux born in lillebonne seinemaritime ...
# Tom Bradley (author)                        tom bradley is an american novelist essayist a...
# Cameron Sharp                               robert cameron sharp born 3 june 1958 is a sco...
# Rajiv Shah                                  rajiv raj shah born march 9 1973 is administra...
# Frits Bolkestein                            frederik frits bolkestein dutch pronunciation ...
# Ren%C3%A9 Froger                            ren froger amsterdam 5 november 1960 is a dutc...
# Lady Clover Honey                           lady clover honey is an american drag queen co...
# Anne Kellas                                 anne kellas is a south african poet reviewer a...
# Gary Fila                                   gary fila born 18 november 1981 is australian ...
# Roger James (footballer)                    roger james born 21 october 1975 is a former a...
# Aled de Malmanche                           aled peter de malmanche born 11 september 1984...
# Jane Shepherdson                            jane elizabeth shepherdson cbe born 23 august ...
# Seiko Lee                                   seiko lee born tokyo japan is a japanese sopra...
# The Zombie Kids                             the zombie kids is a band formed by edgar cand...
# Barbara Kolb                                barbara kolb b hartford connecticut february 1...
# Tevian Dray                                 tevian dray born march 17 1956 is an american ...
# Yevgeniy Chazov                             yevgeniy ivanovich chazov born 10 june 1929 ru...
# Kevon Glickman                              kevon glickman born november 5 1960 is an amer...
# Leslie R. Landrum                           leslie roger landrum is an american botanist s...
# James Cotton (Manitoba politician)          james cotton is a political figure in manitoba...
# Colleen McGill                              colleen mcgill is a renowned canadian designer...
# William Dehning                             william dehning born august 13 1942 is an amer...
# Jimmy Dorrell                               jimmy dorrell is executive director of mission...
# Ant%C3%B3nio Castanheira Neves              antnio castanheira neves born november 8 1929 ...
# Tofusquirrel                                tofusquirrel elizabeth siegel born november 1 ...
# Michael Petrelis                            michael anthony petrelis born january 26 1959 ...
# Ian Mellor                                  ian mellor born 19 february 1950 is an english...
# Antonio Meneses Saillant                    antonio meneses saillant born alfonso antonio ...
# Ventimiglia Giovanni                        giovanni ventimigliagiovanni ventimiglia is fu...
# Antonello Bonci                             antonello bonci born august 3 1966 in pesaro i...
# Adrian Brooks                               adrian brooks born 2 october 1957 in derby eng...
# Ed Rubbert                                  edward rubbert born may 28 1964 is a former am...
# Gerard Toal                                 gerard toal irish gearid tuathail born 1962 in...
# Arturo J. Marcano Guevara                   arturo j marcano guevara a native of caracas v...
# Cam Cairncross                              cameron cairncross born 11 may 1972 is a forme...
# John Taylor (cricketer, born 1937)          john taylor born 9 june 1937 was an english cr...
# Doug Heveron                                doug heveron born march 29 1961 is an american...
# Steven Marrs                                steven marrs born march 11 1967 in landstuhl g...
# Axel Ockenfels                              axel ockenfels born 9 february 1969 is a germa...
# Mike P%C3%A9rez (baseball)                  michael irvin prez ortega born october 19 1964...
# Mario Michel                                mario f michel born 1960 is a saint lucian law...
# Terrell Stone                               terrell stone is an american lutenist and reco...
# James P. Liautaud                           jim liautaud is the creator of pdt process des...
# Robbie Buck                                 robert robbie buck is an australian radio anno...
# Salvatore Russo                             salvatore russo born in nola june 27 1958 is a...
# Masahiko Kimura (bonsai artist)             masahiko kimura kimura masahiko 1940 was born ...
# Jeremy Beck                                 jeremy beck is an american composer who knows ...
# Laura Manuelidis                            laura manuelidis is a physician and neuropatho...
# Pavlo Khazan                                pavlo khazan is a ukrainian public and politic...
# Bernie Hayes                                bernie hayes is an australian singersongwriter...
# Emmanuel Pierre-Antoine                     emmanuel pierreantoine b in haiti is a profess...
# Usama Alshaibi                              usama alshaibi arabic born in baghdad iraq on ...
# Scott Dibble                                scott dibble is a socan award winning canadian...
# Joe B. Mauldin                              joe benson mauldin jr born july 8 1940 is the ...
# Stephen J Smith                             stephen j smith is a senior investigator at th...
# Gulzar Banu                                 gulzar banu born 1963 is an indian politician ...
# David M. Becker                             david m becker now a partner at cleary gottlie...
# Mick O'Brien (footballer, born 1979)        michael george mick obrien born 25 september 1...
# William Kipsang                             william rop kipsang born 26 june 1977 is a ken...
# Tony Mordente                               tony mordente born december 3 1935 is an ameri...
# David Pastr%C5%88%C3%A1k                    david pastrk czech pronunciation davt pastrak ...
# Andreas Alm                                 gert andreas alm born 19 june 1973 in gllivare...
# Rosalind Harris                             rosalind harris 1950 is an american actress wh...
# Renny Pritikin                              renny pritikin was the director of the richard...
# Christy Burke                               christy burke is an independent dublin city co...
# Marc Fleury                                 marc fleury born 1968 is the creator of jboss ...
# Andr%C3%A9 Hurst                            andr hurst born in 1940 in geneva is a helleni...
# Jerry Adams                                 jerry mckee adams faa frs born 17 june 1940 is...
# Otto Happel                                 dr ing otto happel is a global investor he has...
# Ronnie Wallwork                             ronald ronnie wallwork born 10 september 1977 ...
# George Brent Mickum IV                      george brent mickum iv is an american lawyer w...
# John Acquaviva                              john acquaviva born in 1963 is an italianborn ...
# Jose Luis Nazario, Jr.                      sergeant jose luis nazario jr born 1980 is the...
# Jimmy Lewis (surfer)                        jimmy lewis is a hawaiian surfer sailor and su...
# Henry Honiball                              henry william honiball born 1 december 1965 is...
# Randal Quarles                              randal keith quarles born september 5 1957 in ...
# Kat Coiro                                   katherine cunninghameves known as kat coiro is...
# Peter Bailey                                peter bailey born september 16 1980 is an amer...
# Owen Temple                                 owen temple born september 4 1976 in kerrville...
# Logan Aldridge                              wesley logan aldridge born january 25 1991 is ...
# Tobias Frere-Jones                          tobias frerejones born tobias edgar mallory jo...
# Davi Kopenawa Yanomami                      davi kopenawa yanomami name also written davi ...
# Roland De Wolfe                             roland de wolfe born 1979 in london is an engl...
# Kim Kirkpatrick                             kim kirkpatrick born 1952 is a landscape photo...
# Judith Jacob                                judith jacob born 13 december 1961 is a britis...
# Glen Pine                                   glen william pine is an american musician and ...
# Keith Jennings (basketball)                 keith russell mister jennings born november 2 ...
# Tony Lundon                                 anthony william james tony lundon born 13 apri...
# David Vanacore                              david vanacore is a multiaward winning televis...
# Jeff Mauro                                  jeff mauro is the host of the food network ser...
# Meddy Ford                                  meddy ford born 13 may 1989 is a former britis...
# Dave Chomiak                                david walter chomiak born february 15 1953 is ...
# Ernestine Huckleby                          ernestine huckleby 8 years old became the face...
# Jimmy Johnson (cartoonist)                  jimmy johnson is an american comic strip carto...
# Alexi Lalas                                 panayotis alexander alexi lalas born june 1 19...
# Gordon Wu                                   sir gordon wu yingsheun gbs kcmg fice simplifi...
# Jon Bounds                                  jon bounds is a blogger freelance social media...
# James Caan (entrepreneur)                   james caan cbe born nazim khan 28 december 196...
# David Eldridge (dramatist)                  david eldridge born 20 september 1973 is an en...
# Atu Emberson Bain                           atu emberson bain is a fijian political leader...
# Brett Hull                                  brett andrew hull born august 9 1964 is a cana...
# Keyshia Cole                                keyshia cole born october 15 1981 is an americ...
# Jeoff Long                                  jeoffrey keith long born october 9 1941 is an ...
# Marcus Vick                                 marcus deon vick born march 20 1984 is a forme...
# Tom Noddy                                   tom noddy is the stage name of an american ent...
# Guy Sorman                                  guy sorman born march 10 1944 paris france is ...
# Stephen Cassidy                             stephen cassidy is the president of the unifor...
#                                                                   ...
# Luz Mar%C3%ADa Umpierre                     luz mara luzma umpierreherrera born in 1947 sa...
# Alastair Cranston                           alastair cranston is a scottish national party...
# Mark O'Hare                                 mark ohare born july 18 1968 is an american ca...
# Solomon Berewa                              solomon ekuma dominic berewa born 6 august 193...
# Dean Lukin                                  dinko dean lukin oam born 26 may 1960 in sydne...
# Ken Wyniemko                                ken wyniemko is one of two former prisoners in...
# Dale Craigwell                              dale a craigwell born april 24 1971 in toronto...
# Chua Tian Chang                             chua tian chang born 21 december 1963 better k...
# Denis Lill                                  denis lill born 22 april 1942 is a new zealand...
# Bob Tyler                                   bob tyler born july 4 1932 is a former america...
# Paul G                                      paulo george marques joao born march 31 better...
# Tom Spilsbury                               tom spilsbury born in swindon england in 1976 ...
# Alexenia Dimitrova                          alexenia dimitrova is a bulgarian journalist a...
# Orel Hershiser                              orel leonard hershiser iv born september 16 19...
# Humberto Barbosa                            humberto lus rodrigues barbosa is a portuguese...
# John Deary                                  john steele deary born october 18 1962 in orms...
# Bernard M. Judge                            bernard judge is an american journalist who ha...
# Kakha Kaladze                               kakhaber kakha kaladze georgian kaxabr kaladz ...
# Sharwan Kumar                               sharwan kumar is a member of the 14th rajastha...
# Balendu Sharma Dadhich                      balendu sharma dadhich hindi is an indian tech...
# Tonton David                                tonton david is a french reggae singer born in...
# Nick Kosovich                               nick kosovich is a professional ballroom dance...
# Steven Whyte                                steven whyte born 17 march 1969 is a sculptor ...
# Inge Br%C3%BCck                             inge brck born 12 october 1936 in mannheim is ...
# Young Doe                                   charles mcclure born 19800401april 1 1980 also...
# Hasso Spode                                 hasso spode born 1951 in friedrichshagen is a ...
# Calvin Plummer                              calvin plummer born 14 february 1963 is an eng...
# Steve Soboslai                              steve soboslai born october 30 1980 is an amer...
# Philip D. Murphy                            philip d murphy born 1957 is an american busin...
# Mark Giacheri                               mark giacheri born sydney 1 february 1969 is a...
# Herbert Allan Fogel                         herbert allan fogel born 1929 is a former unit...
# Farooq Sobhan                               farooq sobhan born 17 september 1940 is a form...
# Tony Smith (speed skater)                   tony lee smith born 25 dec 1961 in christchurc...
# Jenna Lee-James                             jenna leejames is a british actress who has pl...
# Steve Spurrier                              stephen orr steve spurrier born april 20 1945 ...
# Manohar Lal                                 manohar lal born june 3 1938 is an indian poli...
# Hiltrud Strasser                            dr hiltrud strasser born 1943 leipzig germany ...
# John E. Kozar                               monsignor john e kozar is a native of pittsbur...
# Denise Faye                                 denise faye greenbaum professionally known as ...
# Tommy Ahlers                                tommy ahlers born 18 november 1975 is a danish...
# Fran%C3%A7ois Regnault                      franois regnault french o born 1938 is a frenc...
# Kimiko Kasai                                kimiko kasai born december 15 1945 in kyoto ja...
# Mal Fletcher                                mal fletcher born 1957 in melbourne australia ...
# Russell Downing                             russell downing born 23 august 1978 is an engl...
# Kimberly J. Lee                             kimberly j lee md is a facial plastic and reco...
# Robbie Brightwell                           robert robbie ian brightwell mbe born 27 octob...
# Kenneth Radnofsky                           kenneth a radnofsky born july 31 1953 bryn maw...
# John Abraham (professor)                    dr john p abraham is a professor of thermal an...
# Anders Norudde                              anders norudde born anders stake 1960 is a swe...
# Karen Hines                                 karen hines is a canadian actress writer and d...
# Ivan Pinheiro                               ivan martins pinheiro born 18 march 1946 is a ...
# Elliotte Rusty Harold                       elliotte rusty harold is the author of several...
# Marcus Hummon                               grammy winner marcus hummon has enjoyed a succ...
# Jamie Oldaker                               james jamie oldaker is an american rock music ...
# Kate Rogers                                 kate rogers is the cousin of grand central rec...
# Craig Reid (footballer, born 1985)          craig kevin p reid born 17 december 1985 is an...
# Edward Sequeira                             edward sequeira popularly known as eddie was o...
# Alex Klein                                  alex klein born 1964 porto alegre is an oboist...
# Abraham Mauricio Salazar                    abraham mauricio salazar born 1957 is a nahuat...
# Julius Rebek                                julius rebek jr born april 11 1944 is a hungar...
# Monica Dacon                                dame monica jessie dacon ne sheen dbe cmg born...
# Yvon Joseph                                 yvon joseph born october 31 1957 is a retired ...
# Teuvo Kohonen                               teuvo kohonen born july 11 1934 is a prominent...
# Hannu-Pekka H%C3%A4nninen                   hannupekka hoopi hnninen born 27 july 1952 hel...
# Claire Wolfe                                claire wolfe is a libertarian author and colum...
# Moshe Levy (author)                         moshe levy is an author and a survivor of the ...
# Tom Phardel                                 tom phardel born 1950 michigan is an american ...
# Paul Neebe                                  paul neebe is an american classical trumpeter ...
# Nicky English                               nicholas j nicky english born 1962 is an irish...
# Laurie Levenson                             laurie l levenson is a professor of law willia...
# Ed Doherty (politician)                     edward joseph ed doherty born may 22 1949 is a...
# Lance Williams and Mark Fainaru-Wada        lance williams and mark fainaruwada coauthored...
# Johanna Debreczeni                          johanna debreczeni pronounced debra chaney bor...
# Imtiaz Ahmed (brigadier)                    brigadier imtiaz ahmed also known as imtiaz bi...
# Ihor Miroshnychenko                         ihor miroshnychenko ukrainian is a ukrainian s...
# Anthony Gelsomino                           anthony gelsomino born december 2 1970 is an a...
# Sasha Jackson                               sasha jackson is a british actress from windso...
# Stone (singer)                              annie gautrat better known by her stage name s...
# Artis Pabriks                               artis pabriks born 22 march 1966 is a latvian ...
# Achille Casanova                            achille casanova born 1941 is a swiss journali...
# Suresh K. Nair                              suresh knair born 1971 in adakkaputhur kerala ...
# Andy White (singer-songwriter)              andy white born 28 may 1962 is a northern iris...
# Lim Ding Wen                                lim ding wen born september 21 1999 is a young...
# Khaled Samy Abdallah Ismail                 khaled samy abdallah ismail is a dual canadian...
# Susan C. Lee                                susan clair lee chinese pinyin l fngqin born m...
# Frank Gore                                  franklin delano frank gore born may 14 1983 is...
# Paul Germain                                paul germain is an american animation screenwr...
# Jan Nezmar                                  jan nezmar born 5 july 1977 in opava is a form...
# Linda Strommen                              linda strommen is an american oboist she is pr...
# Winslow Eliot                               winslow eliot born august 19 1956 is an americ...
# Lillian Lincoln                             lillian lincoln lambert is an africanamerican ...
# Chris White (musician)                      christopher taylor chris white born 7 march 19...
# Anita Lipnicka                              anita lipnicka born june 13 1975 in piotrkw tr...
# Lloyd Lindsay Young                         lloyd lindsay young born september 4 1941 is a...
# Robert Wincer                               robert colin wincer born 2 april 1952 is a for...
# Shirley Bottolfsen                          shirley bottolfsen born 12 february 1934 is an...
# Derrill Osborn                              derrill radcliff osborn is a retired american ...
# Marc Scarpa                                 marc scarpa born september 25 1969 in new york...
# Svein Holden                                svein holden born 23 august 1973 is a norwegia...
# Johnny Pritchett                            johnny pritchett born 15 february 1943 is an e...
# Paolo Rossi                                 paolo rossi born 23 september 1956 is an itali...
# Brett Williams (offensive lineman)          brett weston williams born may 2 1980 is a for...
# Daryl Hawk                                  daryl hawk is a documentary photographer and o...
# Jeffrey Nape                                jeffrey nape cmg was until the 2012 election s...
# Greg Lake (radio personality)               greg lake born 1960 as gregory alan whaley has...
# N. K. Naik                                  professor niranjan krishna naik with 38 years ...
# Melanne Verveer                             melanne verveer is the executive director of t...
# Homa Katouzian                              homa katouzian born homayoun katouzian persian...
# Carl Nixon                                  carl nixon born 1967 is a new zealand novelist...
# Kayton Kimberly                             kayton kimberly born september 22 1969 is an a...
# Jim Dator                                   james allen jim dator is professor and directo...
# Kevin Clark (basketball)                    kevin clark is an assistant mens basketball co...
# Justin Huish                                justin huish is an american double olympic cha...
# Stephanie Nyombayire                        stephanie nyombayire born december 1986 is a r...
# Kate Felus                                  kate felus born 1971 is a designedlandscape hi...
# Alana Cordy-Collins                         alana kathleen cordycollins is professor of an...
# Marco Antonio Zago                          marco antonio zago b january 11 1946 birigi so...
# David Dudley Dowd, Jr.                      david dudley dowd jr born 1929 is a united sta...
# Debbie Reynolds                             debbie reynolds born april 1 1932 is an americ...
# Lamar King                                  lamar king born august 10 1975 is a former ame...
# Tyler Lockett                               tyler lockett born september 28 1992 is an ame...
# Bill Boggs                                  william bill boggs iii born july 11 1946 is an...
# Bernadette Benson                           bernadette benson is a canadian born athlete s...
# Blake Russell                               blake russell ne phillips born july 24 1975 is...
# Ben Hogestyn                                ben hogestyn born ben schieferstein on novembe...
# Marcos Hernandez (singer)                   marcos hernandez was born in phoenix arizona i...
# Matt Foreman (activist)                     matt foreman is an american lesbian gay bisexu...
# H. C. Erik Midelfort                        hc hans christian erik midelfort born 1942 is ...
# Marc Sneyd                                  marc sneyd is an english professional rugby le...
# John Arigo                                  john hartley ward arigo born december 10 1978 ...
# Wioletta Grzegorzewska                      wioletta grzegorzewska wioletta greg9 february...
# Juma al-Dossary                             jumah mohammed abdul latif al dossari arabic i...
# Genie (feral child)                         genie born 1957 is the pseudonym of a feral ch...
# Paul Foytack                                paul eugene foytack born november 16 1930 in s...
# Mounir Khairallah                           mounir khairallah born 2 january 1953 is the e...
# Shreya Ghoshal                              shreya ghoshal born 12 march 1984 is an indian...
# Matt Greenhalgh                             matt greenhalgh is an english screenwriteran a...
# C. V. Madhukar                              c v madhukar is the director of investments wi...
# Roger Bossard                               roger bossard is the current chicago white sox...
# Sergey Erzrumyan                            sergey erzrumyan born on 22 november 1980 is a...
# 8th Arjia Rinpoche                          8th agya hotogtu lobsang tubten jigme gyatso t...
# David Leslie (rugby union)                  david leslie born 14 april 1952 is a former sc...
# Rick Maybury                                rick maybury born 1954 is a british technology...
# Lope Navo                                   lope navo born 1980 is a photographer painter ...
# Bonnie Garcia                               bonnie garcia is a california politician she w...
# Mike Padden                                 michael j mike padden born november 13 1946 is...
# Randell Tiongson                            speaker trainer writer columnist radio show ho...
# Kurt Luby                                   kurt luby born 6 march 1963 in bolton lancashi...
# Ray Daviault                                raymond joseph robert daviault born may 27 193...
# David Williams (journalist)                 david williams was a journalist with the west ...
# H%C3%A9ctor Bidonde                         hctor pastor bidonde born march 3 1937 is a no...
# Gary Dunham                                 gary dunham born march 25 1951 is an american ...
# Menderes T%C3%BCrel                         menderes mehmet tevfik trel born 11 july 1964 ...
# Horace Arnold                               horace emmanuel arnold or horacee arnold born ...
# Mary Soderstrom                             mary soderstrom is a novelist short story and ...
# Geills Turner                               geills mccrae kilgour turner first name pronou...
# Barbara Coombs Lee                          barbara coombs lee pa fnp jd born 1947 is an a...
# Paul Ramsey (politician)                    paul ramsey is a canadian academic and politic...
# Hu Xiaomei                                  hu xiaomei chinese is a chinese radio personal...
# Leopoldo Fern%C3%A1ndez                     leopoldo fernndez ferreira born 22 may 1952 is...
# Geneva Overholser                           geneva overholser is an independent journalist...
# Jeff Gray (baseball, born 1963)             jeffrey edward gray born april 10 1963 in rich...
# Tilly Vosburgh                              tilly vosburgh born 17 december 1960 is an eng...
# E. T. Mohammed Basheer                      e t mohammed basheer born 1946 malayalam born ...
# Craig Davis (Australian footballer)         craig davis born 2 october 1954 in ross tasman...
# Patricia Rhomberg                           patricia rhomberg born 15 september 1953 is an...
# Mike Bruhert                                michael edwin bruhert born june 21 1951 is a f...
# Jack Swagger                                donald jacob jake hager born march 24 1982 is ...
# Jonathan R. Steinberg                       jonathan r steinberg is a former judge of the ...
# Antonio Guadagnini                          antonio guadagnini bassano del grappa 25 augus...
# Winston Chow                                winston kh chow is a student leader and commun...
# Jim Eddy                                    jim eddy is a football coach who worked in the...
# Edgar Renter%C3%ADa                         edgar enrique rentera herazo spanish pronuncia...
# Dave MacRae                                 dave macrae born 2 april 1940 auckland new zea...
# Donald Keough                               donald r keough born 1927 is an american busin...
# Julie Brill                                 julie brill was sworn in as a commissioner of ...
# Julia Galloway                              julia galloway is a potter who creates utilita...
# J%C3%B8rgen Ingmann                         jrgen ingmann born 26 april 1925 is a musician...
# Nicholas Rees                               nicholas rees born february 17 1982 in nassau ...
# New Science Projects                        new science projects is a blues punk band from...
# Ron C. Bigelow                              ron c bigelow born 1948 is the eighth mayor of...
# John Heyman                                 john heyman born 1933 in leipzig germany is a ...
# Beth Dunkenberger                           beth dunkenberger is in her second season with...
# Becky Garcia                                becky garcia born 13 september 1983 is a flywe...
# Nikolay Kovalyov (politician)               nikolai dmitrievich kovalyov russian born augu...
# Yodit Getahun                               yodit getahun born 12 february 1985 was the mi...
# Brad Huse                                   brad huse born june 27 1966 is an american col...
# John Clifford Wallace                       john clifford wallace born december 11 1928 is...
# Emilie Brown                                emilie colleen de azevedo brown born january 2...
# Kaid Mohamed                                kaid yusef mohamed born 23 july 1984 is a wels...
# Morinosuke Kawaguchi                        morinosuke kawaguchi b may 1 1961 in ashiya hy...
# A. N. Yiannopoulos                          athanassios nicholas yiannopoulos born march 1...
# Henrik Lund-Nielsen                         henrik lundnielsen born february 3 1965 in nyb...
# Peter Davison (composer)                    peter davison is a composer and instrumentalis...
# Calvin A. Grant                             calvin alexander grant md is an american ophth...
# Roman Polanski                              roman polanski born rajmund roman thierry pola...
# Nasser Kara                                 nasser kara is a malawian politician who was c...
# Jim Casey (footballer)                      jim casey born august 2 1957 in glasgow is a r...
# James Blanchard (scientist)                 dr james blanchard is a professor of community...
# Gianluigi Zuddas                            gianluigi zuddas born 1943 is an italian autho...
# Alan Musgrave                               alan musgrave born c1940 is an english born ne...
# Julian Dawes                                julian dawes born 1942 is an english composer ...
# Eddie Landsberg                             eddie landsberg born october 2 1971 is a tokyo...
# Chris Costner Sizemore                      chris costner sizemore born april 4 1927 in ed...
# James Morris (bass-baritone)                james morris born 10 january 1947 is a leading...
# Richard Thompson (footballer, born 1969)    richard john thompson born 11 april 1969 in ha...
# Charlie Piggott                             charlie piggott born 14 july 1948 is an irish ...
# Eric Naposki                                eric andrew naposki born december 20 1966 is a...
# Michael J. Padilla                          michael j padilla is the former director of th...
# Edward W. Scott                             edward w ed scott jr is an american businessma...
# Jeff Pegues                                 jeffrey pegues born in 1974 in washington dc i...
# Dove Bradshaw                               dove bradshaw born september 24 1949 in new yo...
# Andy Ihnatko                                andy ihnatko ntkois a technology journalist fo...
# Kim Pensyl                                  kim pensyl is a popjazz and new age music keyb...
# Steven Myers                                not to be confused with steven myers politicia...
# Sabitri Mitra                               sabitri mitra is an indian politician belongin...
# Roni Lynn Deutch                            roni lynn deutch is a former tax attorney and ...
# Simon Vega                                  simon h vega born october 8 1935 is a retired ...
# Cho Oh-hyun                                 seorak musan cho oh hyun born in 1932 in mirya...
# Gail Kulick Jackson                         gail kulick jackson born may 29 1959 is a minn...
# Mokob%C3%A9                                 mokob traor better known by the mononym mokob ...
# F. Enzio Busche                             friedrich enzio busche born 5 april 1930 dortm...
# Christian Wiman                             christian wiman is an american poet and editor...
# Ellyn Setnor Bogdanoff                      ellyn setnor bogdanoff born october 17 1959 wa...
# Katya Adler                                 katya adler born 1972 is a british journalist ...
# Anthony-Noel Kelly                          anthonynoel kelly born 1956 is a british artis...
# Mignon Clyburn                              mignon l clyburn born march 22 1962 is a commi...
# Charles A. Miller                           charles a miller born october 27 1937 in washi...
# Rodolfo Parada                              rodolfo parada lillo is a chilean musician com...
# Giwi Margwelaschwili                        giwi margwelaschwili georgian born december 14...
# Geoffrey Kipsang                            geoffrey kipsang kamworor born 22 november 199...
# Dave Nilsson                                david wayne nilsson born 14 december 1969 is a...
# Jessica Jordan                              jessica anne jordan burton born 6 may 1984 in ...
# Marina Mulyayeva                            marina vladimirovna mulyayeva kazakh born apri...
# Jo%C3%ABl de Rosnay                         jol de rosnay born 1937 phd from the massachus...
# Amy Jenkins                                 amy jenkins born 1966 in london is an english ...
# Roy Zimmerman (satirist)                    roy zimmerman born october 7 1957 is an americ...
# George Krause                               george krause born 1937 philadelphia pennsylva...
# Sean Slade                                  sean slade b november 14 1957 lansing michigan...
# Lynne Lipton                                lynne lipton is an american film stage televis...
# Rod Wilt                                    rod wilt is a former republican member of the ...
# Scott Baker (judge)                         sir thomas scott gillespie baker born 10 decem...
# Dragoljub Ojdani%C4%87                      dragoljub ojdani serbian cyrillic born june 1 ...
# Oz Bengur                                   osman oz bengur born february 23 1949 is an am...
# Dee Brown (basketball, born 1968)           decovan kadell dee brown born november 29 1968...
# Olari Elts                                  olari elts born april 27 1971 in tallinn eston...
# Scott F. Crago                              scott francis crago born july 26 1963 twin bro...
# David Cass (footballer)                     david william royce cass born 27 march 1962 in...
# Keith Elias                                 keith hector elias born february 3 1972 in lac...
# Fawaz Damrah                                fawaz mohammed damrah arabic fawwz damra was t...
# Name: text, Length: 59071, dtype: object

# %%
from sklearn.metrics.pairwise import euclidean_distances
obama = count_matrix.getrow(wiki.index.get_loc('Barack Obama'))
bush = count_matrix.getrow(wiki.index.get_loc('George W. Bush'))
biden = count_matrix.getrow(wiki.index.get_loc('Joe Biden'))
obama_bush = euclidean_distances(obama, bush)
obama_biden = euclidean_distances(obama, biden)
bush_biden = euclidean_distances(bush, biden)
print(obama_bush)
print(obama_biden)
print(bush_biden)
# Out:
# [[34.3074336]]
# [[33.01514804]]
# [[32.69556545]]

# %% [markdown]
# ### **Q2) Which of the three pairs has the smallest distance?**
#
# - Obama - Biden
# - Bush - Biden (o)
# - Obama - Bush
# - All had the same distance

# %% [markdown]
# **Note.** Even though common words are swamping out important subtle differences, commonalities in rarer political words still matter on the margin. This is why politicians are being listed in the query result instead of musicians, for example. In the next subsection, we will introduce a different metric that will place greater emphasis on those rarer words.

# %% [markdown]
# ## TF-IDF to the rescue

# %% [markdown]
# * Much of the perceived commonalities between Obama and Barrio were due to occurrences of extremely frequent words, such as "the", "and", and "his".
# * So nearest neighbors is recommending plausible results sometimes for the wrong reasons.
#
# * To retrieve articles that are more relevant, we should focus more on rare words that don't happen in every article. **TF-IDF** (term frequency–inverse document frequency) is a feature representation that penalizes words that are too common.  Let's use Scikit-Learn's implementation of TF-IDF and repeat the search for the 10 nearest neighbors of Barack Obama:
# * I included a longggggggg and detailllllllled description of the given code in the previous section, so I will not explain it again to save space.
#     * The Nearest Neighbor and TFIDF vectorization is almost identical.
#     * If you wonder what these given code means, look at the previous section when we vectorized the articles based on word counts.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# * Now, Try implement your TF-IDF model using the steps we just walked you through.
#     * This time, use `TfidfVectorizer()`.
#     * Also, pass in `max_df=0.97` when you call `TfidfVectorizer()`.
#     * You should obtain a model called `tf_model`, and a matrix called `tfidf_matrix`.
#     * The `Extract word count vectors` section we walked through before might be helpful.
#
# ### Think for a bit...🤔
# * Now take a while and think...why do we pass in `max_df=0.97` into the TfidfVectorizer?
#     * If we use the default `max_df=1.00`, we get back ALL of the words and their tf-idf scores.
#     * If we use the `max_df=0.97`, this will exclude words that appear in more than 97% of the documents.
# * But still, why?
#     * What is tf-idf?
#         * In a nut shell, it is the *ratio* of the overall frequency to the number of documents it appears in.
#     * So what happens if we use all the words?
#         * If a word appears very often, it could still have a high tf-idf score even if it also appears in many documents.
#             * Namely, 'a', 'the', 'he', etc.
#         * Do these common words help when we look at the dataset as a whole?
#             * Nope!
#             * So we get rid of the words that appear in more than 97% of the articles.
# * (Thanks Joshua soooooooooo much on this one!!)

# %%
# Write your answer here!
tfidf_vectorizer = TfidfVectorizer(max_df=0.97)
tfidf_matrix = tfidf_vectorizer.fit_transform(wiki)
tf_model = NearestNeighbors(n_neighbors = 10).fit(tfidf_matrix)

# %%
tf_obama = tfidf_matrix.getrow(wiki.index.get_loc('Barack Obama'))
tf_dist = tf_model.kneighbors(tf_obama)[0]
tf_index = tf_model.kneighbors(tf_obama)[1]
new_wiki = wiki.reset_index()['name']
flat_tf_index = tf_index.flatten()
tf_distances = tf_dist.flatten()
series_tf_index = pd.Series(flat_tf_index)
tf_names = series_tf_index.map(new_wiki)
tf_result = pd.DataFrame({'distance':tf_distances, 'name':tf_names})
tf_result
# Out:
#    distance                     name
# 0  0.000000             Barack Obama
# 1  1.141823                Joe Biden
# 2  1.196133           Samantha Power
# 3  1.202502   Hillary Rodham Clinton
# 4  1.208226  Eric Stern (politician)
# 5  1.223706             Robert Gibbs
# 6  1.228785              Eric Holder
# 7  1.229485              John McCain
# 8  1.231122             Henry Waxman
# 9  1.231126            Jeff Sessions

# %% [markdown]
# ### Let's determine whether this list makes sense.
# * Joe Biden is the Vice President when Obama was in power.
# * Samantha Power is a member of the Democratic Party who served as the 28th United States Ambassador to the United Nations from 2013 to 2017.
# * Hillary Rodham Clinton is the Secretary of State when Obama was in power.
# * John McCain previously served two terms in the United States House of Representatives and was the Republican nominee for president of the United States in the 2008 election, which he lost to Barack Obama.
# * Henry Arnold Waxman is an American Democratic politician who served as the U.S. Representative for California's 33rd congressional district from 1975 until 2015.
# * Jeff Sessions served as United States Senator from Alabama from 1997 to 2017 during Obama's rule, then he resigned from the position in order to serve in the Trump administration.
#
# Clearly, the results are more plausible with the use of TF-IDF. 😄

# %% [markdown]
# ## Obama and Hillary Rodham Clinton TF-IDF comparison

# %% [markdown]
# Let's take a look at the word vector for Obama and Hillary Rodham Clinton's pages. Notice that TF-IDF representation assigns a weight to each word. This weight captures relative importance of that word in the document. Let us sort the words in Obama's article by their TF-IDF weights; we do the same for Hillary Rodham Clinton's article as well.

# %%
def top_words_tf_idf(name):
    # Get the most frequent words in the given person's wikipedia page.
    word = tfidf_matrix.getrow(wiki.index.get_loc(name)).toarray().flatten()
    indices = tfidf_vectorizer.get_feature_names()
    words = pd.Series(word, index = indices)
    words = words.sort_values(ascending=False).reset_index()
    words.rename(columns={'index':'word',0:'count'}, inplace=True)
    return words

# %%
obama_tf_idf = top_words_tf_idf('Barack Obama')
obama_tf_idf[0:10]
# Out:
#          word     count
# 0       obama  0.398184
# 1         act  0.271722
# 2        iraq  0.165602
# 3         law  0.157834
# 4     control  0.143838
# 5          us  0.133995
# 6     ordered  0.133499
# 7    military  0.130355
# 8  democratic  0.124986
# 9    response  0.120199

# %%
hillary_tf_idf = top_words_tf_idf('Hillary Rodham Clinton')
hillary_tf_idf[0:10]
# Out:
#         word     count
# 0    clinton  0.458690
# 1        she  0.267178
# 2       lady  0.254605
# 3     rodham  0.179110
# 4         us  0.141589
# 5  secretary  0.137810
# 6      state  0.130819
# 7         to  0.130005
# 8      first  0.128670
# 9   arkansas  0.127195

# %% [markdown]
# Using the **join** operation we learned earlier, try your hands at computing the common words shared by Obama's and Hillary's articles. Sort the common words by their TF-IDF weights in Obama's document.

# %%
### Students should write code to answer the question.
combined = obama_tf_idf.join(hillary_tf_idf.set_index('word'),rsuffix='_1', on = 'word')
combined.rename(columns={'count':'Obama','count_1':'Hillary'}, inplace=True)
print(combined[0:5])
# Out:
#       word     Obama   Hillary
# 0    obama  0.398184  0.080143
# 1      act  0.271722  0.061526
# 2     iraq  0.165602  0.074995
# 3      law  0.157834  0.071477
# 4  control  0.143838  0.000000

# %% [markdown]
# The first 5 words should say: obama, act, iraq, law, control.

# %% [markdown]
# ### Q3) What is the TF-IDF weight assigned to the word "iraq" for Hillary's page (rounded to the nearest 0.01)? 0.07

# %% [markdown]
# ## Top 5 word comparison to wikipedia corpus revisited

# %% [markdown]
# Among the words that appear in both Barack Obama and Hillary Clinton, take the 5 that have largest weights in Obama. How many of the articles in the Wikipedia dataset contain all of these 5 words?

# %%
wiki = wiki.reset_index()
wiki['word_count'] = wiki['text'].apply(word_counter)

# %% [markdown]
# ### **Q4) Among the words that appear in both Barack Obama and Hillary Clinton pages, take the 5 that have largest weights in Obama. What percentage of the articles in the Wikipedia dataset contain all of these top 5 words? Give answer as a decimal rounded to the nearest 0.0001 - for instance if the percentage found was 0.0817% then state answer as 0.000817.** 0.0033

# %%
### Students should write code to answer the question.
common = set(combined.sort_values('Obama', ascending = False)['word'][0:5])
print(common)
def has_top_words(word_count_vector):
    unique_words = word_count_vector.keys()
    if common.issubset(unique_words):
        return True
    else:
        return False
wiki['has_top_words'] = wiki['word_count'].apply(has_top_words)

wiki['has_top_words'].sum()/len(wiki['has_top_words'])
# Out:
# {'iraq', 'act', 'law', 'obama', 'control'}
# 3.3857561239863894e-05

# %% [markdown]
# ### **Q5) What can you conclude from observing the differences between the top words existance using the count of words and TF-IDF?**
# The 5 most frequently used words for Obama resulted from the count of words are [and, in, of, the, to], and those resulted from TF-IDF are [obama, act, iraq, law, control]. TF-IDF is more reasonable method and penalizes words that are too common.

# %% [markdown]
# ### **Q6) In a paragrah or two, summerize how the choice of Vectorization (Word Count and TF-IDF) affects the nearest neighbor calculations. Discuss the shortcomings of the bag of words approach (word count) in the context of nearest neighbor document retrieval.**

# %% [markdown]
# ### **Q7) What is something you would change about the data or the model to improveTF-IDF document retrieval model in general, so that it can find the most similar wikipedia page for any given wikipedia page query? Justify why you think this change may improve the quality of the model.**
#
# **There are many possible correct answers.**

# %% [markdown]
# ### Well, finally you reached the end of this asignment. Whoo! 🧐
# ### Wait... in case you don't know, there is another notebook you need to do. Whaaat?
# * It's like Erwin Schrödinger's CSE 416 Homework 5.
#     * When I am writing this assignment 4 AM in the morning, you are at a state that you both completed and did not complete all the assignment.
#     * Now, you can observe yourself and make sure you are in a state that you completed all of Assignment 5.
#     * If not, there is a boosting part of Assignment 5 which you can learn all about boosting 🚀!
#
# ### Don't forget to make sure you submitted your quiz AND your notebook!
# ### You might also want to post to this [really cool online discussion board](https://canvas.uw.edu/courses/1271722/discussion_topics) .
