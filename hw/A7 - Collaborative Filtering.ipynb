# %% [markdown]
# # Build a Song Recommender System
# ## Due: Wednesday, May 29rd, by 11:59 pm on Canvas
#
# In this assignment you will
#
# - Explore the song data set.
# - Build two different song recommendation models and make comparisons between the two.
# - Investigate the song recommendations of the item similarity model.
# - For a given song, find the most similar songs.
#
# Copyright ©2018 Emily Fox. All rights reserved. Permission is hereby granted to students registered for University of Washington CSE/STAT 416 for use solely during Spring Quarter 2019 for purposes of the course. No other use, copying, distribution, or modification is permitted without prior written consent. Copyrights for third-party components of this work must be honored. Instructors interested in reusing these course materials should contact the author.

# %%
import pandas as pd
import numpy as np
import operator
from sklearn.model_selection import train_test_split
from sklearn.decomposition import NMF

# %%
song_data = pd.read_csv(filepath_or_buffer = '/data/song_data.csv')
song_data = song_data.iloc[0:50000]
song_data
# Out:
#                                         user_id             song_id  \
# 0      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# 5      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODDNQT12A6D4F5F7E
# 6      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODXRTY12AB0180F3B
# 7      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFGUAY12AB017B0A8
# 8      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFRQTD12A81C233C0
# 9      b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOHQWYZ12A6D4FA701
# 10     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOIYTOA12A6D4F9A23
# 11     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOIZAZL12A6701C53B
# 12     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOJNNUA12A8AE48C7A
# 13     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOJPFQG12A58A7833A
# 14     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOKRIMP12A6D4F5DA3
# 15     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOLLGNU12AF72A4D4F
# 16     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOMGIYR12AB0187973
# 17     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOMLMKI12A81C204BC
# 18     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOMSQJY12A8C138539
# 19     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SONSAEZ12A8C138D7A
# 20     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOOKGRB12A8C13CD66
# 21     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOPCVQE12AC468AF36
# 22     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOQIVUD12AB01821D2
# 23     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOQJLDY12AAF3B456D
# 24     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOQLCKR12A81C22440
# 25     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SORPMYJ12AF729EB90
# 26     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SORQHCG12A58A7EEBA
# 27     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SORUFVF12AB018230B
# 28     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SORWLTW12A670208FA
# 29     b80344d063b5ccb3212f76538f3d9e43d87dca9e  SORZASF12A6D4F8CFA
# ...                                         ...                 ...
# 49970  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOIOHLX12A6702162F
# 49971  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOIXXSG12A8C13C400
# 49972  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOJCPIH12A8C141954
# 49973  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOJEUAB12A6701D938
# 49974  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOJEVHC12A8C13C3E5
# 49975  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOKDBWF12A6701F0C9
# 49976  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOLKOYH12A8C135EF8
# 49977  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOPSLVR12A8C1430A8
# 49978  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOPUCYA12A8C13A694
# 49979  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SORYLNP12A8C13C3E7
# 49980  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOSRKMU12A58A7D782
# 49981  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOSXPFU12AB017FE27
# 49982  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOUXLHG12AB017C30C
# 49983  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOUXNNU12A67020A48
# 49984  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOXRPBX12AB018222D
# 49985  f3f3c750dd178ef1add801d9efc0982f95c9b00e  SOYKBBJ12A8AE45968
# 49986  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOAAWEE12A6D4FBEC8
# 49987  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOARUPP12AB01842E0
# 49988  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOAUFOF12AB0180C65
# 49989  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOAUWYT12A81C206F1
# 49990  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOBOUPA12A6D4F81F1
# 49991  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOBXHDL12A81C204C0
# 49992  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOCQJYB12AB017E855
# 49993  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOCVBFV12A6701FB94
# 49994  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SODCNJX12A6D4F93CB
# 49995  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOGAOAU12A8C140E54
# 49996  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOIZLKI12A6D4F7B61
# 49997  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOJEYPO12AAA8C6B0E
# 49998  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOJJYDE12AF729FC16
# 49999  33dc1bec8ee699bd1ad4f1a5b238e2529a283794  SOKPSFX12A58A7B5CF
#
#        listen_count                                              title  \
# 0                 1                                           The Cove
# 1                 2                                    Entre Dos Aguas
# 2                 1                                           Stronger
# 3                 1                                     Constellations
# 4                 1                                       Learn To Fly
# 5                 5                       Apuesta Por El Rock 'N' Roll
# 6                 1                                      Paper Gangsta
# 7                 1                                     Stacked Actors
# 8                 1                                      Sehr kosmisch
# 9                 1                      Heaven's gonna burn your eyes
# 10                1                                     Let It Be Sung
# 11                5  I'll Be Missing You (Featuring Faith Evans & 1...
# 12                1                                         Love Shack
# 13                1                                            Clarity
# 14                5                          I?'m A Steady Rollin? Man
# 15                1                                     The Old Saloon
# 16                6                   Behind The Sea [Live In Chicago]
# 17                1                                           Champion
# 18                1                                           Breakout
# 19                1                                        Ragged Wood
# 20                1                                            Mykonos
# 21                1                                       Country Road
# 22                1                                              Oh No
# 23                1                               Love Song For No One
# 24                1                                    Jewels And Gold
# 25                1                                            Warning
# 26                1                                                 83
# 27                1                                               Neon
# 28                1                                         The Middle
# 29                2                                       High and dry
# ...             ...                                                ...
# 49970             1                  A Man/Me/Then Jim (Album Version)
# 49971             1                                          re:stacks
# 49972             1                                Hallowed Be My Name
# 49973             2                                    Flesh Into Gear
# 49974             1                                              Flume
# 49975             3                                             Oh Boy
# 49976             1                                              I Try
# 49977             1                                A Little Bit Longer
# 49978             2                                             Canada
# 49979             1                                           Lump Sum
# 49980             1                                         Hallelujah
# 49981             1                    The Calculation (Album Version)
# 49982             1            Man Of A Thousand Faces (Album Version)
# 49983             1                                           Hey Mama
# 49984             1                             This Tornado Loves You
# 49985             1                           Detached (Album Version)
# 49986             1                         Hallelujah (Album Version)
# 49987             1                                       Up Up & Away
# 49988             3                  Seven Nation Army (Album Version)
# 49989             2                                               Undo
# 49990             2                              Sincerité Et Jalousie
# 49991             2                                           Stronger
# 49992             2                         Headstrong (Album Version)
# 49993             1                                        Don't Speak
# 49994             2                   Jamaica Roots II(Agora E Sempre)
# 49995             1                Medley: Let Me Talk To You/ My Love
# 49996             1  Supermassive Black Hole (Twilight Soundtrack V...
# 49997             1                          Ignorance (Album Version)
# 49998             1                             Two Is Better Than One
# 49999             1  Tie Me Down [feat. Ray J] (Amended Album Version)
#
#                                                   artist  \
# 0                                           Jack Johnson
# 1                                          Paco De Lucia
# 2                                             Kanye West
# 3                                           Jack Johnson
# 4                                           Foo Fighters
# 5                                    Héroes del Silencio
# 6                                              Lady GaGa
# 7                                           Foo Fighters
# 8                                               Harmonia
# 9            Thievery Corporation feat. Emiliana Torrini
# 10     Jack Johnson / Matt Costa / Zach Gill / Dan Le...
# 11                                            Puff Daddy
# 12                                            The B-52's
# 13                                            John Mayer
# 14                                        Robert Johnson
# 15                                     The Lonely Island
# 16                                    Panic At The Disco
# 17                                            Kanye West
# 18                                          Foo Fighters
# 19                                           Fleet Foxes
# 20                                           Fleet Foxes
# 21                             Jack Johnson / Paula Fuga
# 22                                           Andrew Bird
# 23                                            John Mayer
# 24                                   Angus & Julia Stone
# 25                                               Incubus
# 26                                            John Mayer
# 27                                            John Mayer
# 28                                       Jimmy Eat World
# 29                                         Jorge Drexler
# ...                                                  ...
# 49970                                         Rilo Kiley
# 49971                                           Bon Iver
# 49972                                         HAMMERFALL
# 49973                                                CKY
# 49974                                           Bon Iver
# 49975                            Cam'Ron / Juelz Santana
# 49976                        Talib Kweli / Mary J. Blige
# 49977                                     Jonas Brothers
# 49978                                   Five Iron Frenzy
# 49979                                           Bon Iver
# 49980                                       Jeff Buckley
# 49981                                     Regina Spektor
# 49982                                     Regina Spektor
# 49983                                         Kanye West
# 49984                                          Neko Case
# 49985                                         Spineshank
# 49986                                           Paramore
# 49987                                           Kid Cudi
# 49988                                  The White Stripes
# 49989                                              Björk
# 49990                                    Alliance Ethnik
# 49991                                         Kanye West
# 49992                                              Trapt
# 49993                                           No Doubt
# 49994                                           Natiruts
# 49995                   Justin Timberlake Featuring T.I.
# 49996                                               Muse
# 49997                                           Paramore
# 49998             Boys Like Girls featuring Taylor Swift
# 49999                                           New Boyz
#
#                                                     song
# 0                                The Cove - Jack Johnson
# 1                        Entre Dos Aguas - Paco De Lucia
# 2                                  Stronger - Kanye West
# 3                          Constellations - Jack Johnson
# 4                            Learn To Fly - Foo Fighters
# 5      Apuesta Por El Rock 'N' Roll - Héroes del Sile...
# 6                              Paper Gangsta - Lady GaGa
# 7                          Stacked Actors - Foo Fighters
# 8                               Sehr kosmisch - Harmonia
# 9      Heaven's gonna burn your eyes - Thievery Corpo...
# 10     Let It Be Sung - Jack Johnson / Matt Costa / Z...
# 11     I'll Be Missing You (Featuring Faith Evans & 1...
# 12                               Love Shack - The B-52's
# 13                                  Clarity - John Mayer
# 14            I?'m A Steady Rollin? Man - Robert Johnson
# 15                    The Old Saloon - The Lonely Island
# 16     Behind The Sea [Live In Chicago] - Panic At Th...
# 17                                 Champion - Kanye West
# 18                               Breakout - Foo Fighters
# 19                             Ragged Wood - Fleet Foxes
# 20                                 Mykonos - Fleet Foxes
# 21              Country Road - Jack Johnson / Paula Fuga
# 22                                   Oh No - Andrew Bird
# 23                     Love Song For No One - John Mayer
# 24                 Jewels And Gold - Angus & Julia Stone
# 25                                     Warning - Incubus
# 26                                       83 - John Mayer
# 27                                     Neon - John Mayer
# 28                          The Middle - Jimmy Eat World
# 29                          High and dry - Jorge Drexler
# ...                                                  ...
# 49970     A Man/Me/Then Jim (Album Version) - Rilo Kiley
# 49971                               re:stacks - Bon Iver
# 49972                   Hallowed Be My Name - HAMMERFALL
# 49973                              Flesh Into Gear - CKY
# 49974                                   Flume - Bon Iver
# 49975                   Oh Boy - Cam'Ron / Juelz Santana
# 49976                I Try - Talib Kweli / Mary J. Blige
# 49977               A Little Bit Longer - Jonas Brothers
# 49978                          Canada - Five Iron Frenzy
# 49979                                Lump Sum - Bon Iver
# 49980                          Hallelujah - Jeff Buckley
# 49981   The Calculation (Album Version) - Regina Spektor
# 49982  Man Of A Thousand Faces (Album Version) - Regi...
# 49983                              Hey Mama - Kanye West
# 49984                 This Tornado Loves You - Neko Case
# 49985              Detached (Album Version) - Spineshank
# 49986              Hallelujah (Album Version) - Paramore
# 49987                            Up Up & Away - Kid Cudi
# 49988  Seven Nation Army (Album Version) - The White ...
# 49989                                       Undo - Björk
# 49990            Sincerité Et Jalousie - Alliance Ethnik
# 49991                              Stronger - Kanye West
# 49992                 Headstrong (Album Version) - Trapt
# 49993                             Don't Speak - No Doubt
# 49994        Jamaica Roots II(Agora E Sempre) - Natiruts
# 49995  Medley: Let Me Talk To You/ My Love - Justin T...
# 49996  Supermassive Black Hole (Twilight Soundtrack V...
# 49997               Ignorance (Album Version) - Paramore
# 49998  Two Is Better Than One - Boys Like Girls featu...
# 49999  Tie Me Down [feat. Ray J] (Amended Album Versi...
#
# [50000 rows x 6 columns]

# %% [markdown]
# ## Q1) Of the following artists, which artist has the most number of unique users that have listened to them in this data set?

# %% [markdown]
# - Kanye West
# - Foo Fighters
# - Taylor Swift (o)
# - Lady GaGa

# %%
# Student writes code here
print(song_data.columns)
song_data.groupby(['artist'])['user_id'].count().nlargest(11)
# Out:
# Index(['user_id', 'song_id', 'listen_count', 'title', 'artist', 'song'], dtype='object')
# artist
# Coldplay                  676
# Florence + The Machine    515
# Kings Of Leon             459
# OneRepublic               365
# Taylor Swift              361
# The Black Keys            361
# Eminem                    358
# Justin Bieber             356
# Daft Punk                 354
# Train                     340
# Radiohead                 315
# Name: user_id, dtype: int64

# %% [markdown]
# ## Q2) Of the users that have listened to "Where Is My Mind?" by The Pixies (song_id: SOBBKGF12A8C1311EE), what is the average number of times they listened to that particular song? State answer in decimal format to nearest 0.01.

# %%
# Student writes code here
song_data[song_data['song_id'] == 'SOBBKGF12A8C1311EE']['listen_count'].mean()
# Out:
# 4.5

# %% [markdown]
# ## Q3) Identify the song that has the largest total listen count across all users. Who is the artist of this song?
#
# Hint: Consider using the pandas.groupby(), .sum() and pandas.Series.idxmax()
#
# - Kings of Leon
# - Dwight Yoakam (o)
# - Cold Play
# - Righteous Pigs

# %%
# Student writes code here
max_song = song_data.groupby(['song_id'])['listen_count'].sum().idxmax()
song_data[song_data['song_id'] == max_song]['artist'].head()
# Out:
# 91     Dwight Yoakam
# 182    Dwight Yoakam
# 348    Dwight Yoakam
# 535    Dwight Yoakam
# 646    Dwight Yoakam
# Name: artist, dtype: object

# %% [markdown]
# ## Relevance of top 10 song recommendations
#
# Randomly partition the data into 80% training and 20% test using seed = 0. Build two song recommendation models.
# - The first model is a popularity model that just recommends the 10 most popular songs (in order of popularity) for every user regardless of their listening history. Popularity is measured in the number of users who listned to the song.
# - The second model is an item similarity model, that uses item-item similarities based on users in common.

# %% [markdown]
# ### Create a bag of songs for each user.
#
# This is a matrix where rows represent users and columns represent songs. Matrix(i,j) = number of times user i heard song j.

# %%
#make sure random_state = 1
#use this for popularity model
train, test = train_test_split(song_data, test_size = 0.2, random_state = 1)

# %%
#Making the list of users and songs
songs = list(song_data['song'].unique())
users_train = list(train['user_id'].unique())
users_test = set(test['user_id'].unique())

#Making the siilarity matrix function
def similarity_matrix(data):
    users = list(data['user_id'].unique())
    similarity_matrix = np.zeros((len(users), len(songs)))
    i = 0;
    for user in users:
        songs_heard = list(data[data['user_id'] == user]['song'])
        times_heard = list(data[data['user_id'] == user]['listen_count'])

        for song, times in zip(songs_heard, times_heard):
            index = songs.index(song)
            similarity_matrix[i][index] = times;
        i += 1
    return similarity_matrix

# %%
#use these for similarity model
similarity_train = similarity_matrix(train)
similarity_test = similarity_matrix(test)

# %%
#converting to low rank using NMF
#The inverse transform approximates the listen counts of each song for each user.
#Thus, the prediction k songs with heighest listen counts that the user has not heard
model = NMF(n_components = 10)
out = model.fit_transform(similarity_train)
similarity_train = model.inverse_transform(out)

# %%
def popularity_model(number_of_songs):
    out = train.groupby(by = ['song'], as_index=False)['user_id'].count().\
    nlargest(number_of_songs,'user_id', keep = 'first').iloc[0:number_of_songs]
    out = out.rename(columns = {'user_id': 'total_users'})
    return list(out['song'])

# %%
def similarity_model(user_id, number_of_songs):
    if number_of_songs < 0:
        print('number_of_songs must be non negative')
        return None
    if (user_id in users_train):
        user_heard_songs = set(train[train['user_id'] == user_id]['song'])
        index = users_train.index(user_id)
        user_vector = similarity_train[index].copy()
        
        songs_added = 0
        to_return = []
        while songs_added < number_of_songs:
            best_song_index = np.argmax(user_vector)
            user_vector[best_song_index] = -float('inf');
            best_song = songs[best_song_index]
            if best_song not in user_heard_songs:
                to_return.append(best_song)
                songs_added += 1
        return to_return
    #if user is not in train data, we return the most popular songs
    #this is called a cold start problem.
    #Imagine that you make a new youtube account. What does youtube recommend to you?
    #It has no data on you so it will recommend the most popular videos.
    #This is what is happening here
    else:
        return popularity_model(number_of_songs)

# %% [markdown]
# ## Check that these two models are giving different recommendations for a given user

# %%
popularity_model(10)
# Out:
# ['Sehr kosmisch - Harmonia',
#  'Undo - Björk',
#  "You're The One - Dwight Yoakam",
#  'Dog Days Are Over (Radio Edit) - Florence + The Machine',
#  'Revelry - Kings Of Leon',
#  'Secrets - OneRepublic',
#  'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) - Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner',
#  'Fireflies - Charttraxx Karaoke',
#  'Tive Sim - Cartola',
#  'Hey_ Soul Sister - Train']

# %%
similarity_model(users_train[0], 10)
# Out:
# ['Dancing Shoes - Arctic Monkeys',
#  "Ain't Misbehavin - Sam Cooke",
#  'Tive Sim - Cartola',
#  'Somebody To Love - Justin Bieber',
#  'One Time - Justin Bieber',
#  'Représente - Alliance Ethnik',
#  "Everything You Touch We Touch First (America'S Mexican) - George Lopez",
#  'Alright - Mystikal',
#  'Catch You Baby (Steve Pitron & Max Sanna Radio Edit) - Lonnie Gordon',
#  'Moog Island - Morcheeba']

# %%
def precision_recall(user_list, model_name, number_of_songs):
    true_positive = 0
    false_positive = 0
    true_negative = 9200
    false_negative = 0
    if type(model_name) != str:
        print('model_name parameter must be a string')
        return None
    if number_of_songs < 0:
        print('number_of_songs should be non negative')
        return None
    if number_of_songs > 80:
        print('number_of_songs is too high')
    if model_name.lower() != 'popularity' and model_name.lower() != 'similarity' :
        print('model_name must be \'popularity\' or \'similarity\'')
        return None
    for user in user_list:
        if user not in users_test:
            true_negative -= len(train[train['user_id'] == user]['song'])
            continue
        if model_name.lower() == 'popularity':
            predictions = popularity_model(number_of_songs)
        elif model_name.lower() == 'similarity':
            predictions = similarity_model(user, number_of_songs)
        truth = set(test[test['user_id'] == user]['song'])
        for prediction in predictions:
            if prediction in truth:
                true_positive += 1
                true_negative -= 1
            else:
                false_positive += 1
                true_negative -= 1
        for song in truth:
            if song not in predictions:
                false_negative += 1
                true_negative -= 1
    precision = true_positive / (true_positive + false_positive)
    recall = true_positive / (true_positive + false_negative)
    print('Precision is: ' + str(precision))
    print('Recall is: ' + str(recall))
    return (precision, recall)

# %% [markdown]
# ## Q4) If the popularity model was used to show 10 results to users, on average, what portion of the results would be relevant? State answer in decimal format to nearest 0.01.

# %%
# students write code here
precision_recall(users_train, 'popularity', 10)
#
# Out:
# Precision is: 0.013205374280230326
# Recall is: 0.034472392023248824
# (0.013205374280230326, 0.034472392023248824)

# %% [markdown]
# ## Q5) If the item similarity model was used to show 10 results to users, on average, what portion of the results would be relevant? State answer in decimal format to nearest 0.01.

# %%
# students write code here
precision_recall(users_train, 'similarity', 10)
# Out:
# Precision is: 0.009366602687140116
# Recall is: 0.02445134783044393
# (0.009366602687140116, 0.02445134783044393)

# %% [markdown]
# ## Top song recommendation for a subset of users

# %% [markdown]
# We will now only use the similarity model for the remainder of the assignment. For Q6, take a subset of users **(the first 1000 users)** from the test set. Using the item similarity model, get the top song recommendation for each of these users - refer to the item_similarity documentation on how to do this.

# %%
users_test_subset = []

i = 0
for val in iter(users_test):
    if i == 1000:
        break
    users_test_subset.append(val)
    i += 1

# %% [markdown]
# ## Q6) Which song is the most frequent top song recommendation from the item similarity model for this subset of users?
#
# ### Set number of songs to 10 when retrieving
#
# - "Secrets" by OneRepublic
# - "Undo" by Bjork (o)
# - "The Scientist" by Coldplay
# - "Hey Soul Sister" by Train

# %%
# Students write code here
similarity_model(users_test_subset, 10)
# Out:
# ['Sehr kosmisch - Harmonia',
#  'Undo - Björk',
#  "You're The One - Dwight Yoakam",
#  'Dog Days Are Over (Radio Edit) - Florence + The Machine',
#  'Revelry - Kings Of Leon',
#  'Secrets - OneRepublic',
#  'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) - Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner',
#  'Fireflies - Charttraxx Karaoke',
#  'Tive Sim - Cartola',
#  'Hey_ Soul Sister - Train']

# %% [markdown]
# ## Q7) What percentage of rows in the test set have listen count 1? State answer in decimal format to nearest 0.01.
#
# Note: Unique is not required here

# %%
# Students write code here
len(test[test['listen_count'] == 1])/len(test)
# Out:
# 0.5671

# %% [markdown]
# ## Q8) Compared to the entire test set, how does the precision and recall change if we were to evaluate our item similarity model only on rows (of the test set) with listen count greater than 100? Assume 10 songs are recommended for both populations.
#
# - both precision and recall go down
# - precision goes up, recall goes down
# - precision goes down, recall goes up
# - both precision and recall go up (o)

# %%
users_test_subset = []

for user in users_test:
    sum_of_listen_counts = sum(test[test['user_id'] == user]['listen_count'])
    if sum_of_listen_counts > 100:
        users_test_subset.append(user)

# %%
# Students wrrite solution here
precision_recall(users_test, 'similarity', 10)
# Out:
# Precision is: 0.009316533027873233
# Recall is: 0.024402440244024402
# (0.009316533027873233, 0.024402440244024402)

# %%
precision_recall(users_test_subset, 'similarity', 10)
# Out:
# Precision is: 0.04090909090909091
# Recall is: 0.05806451612903226
# (0.04090909090909091, 0.05806451612903226)
